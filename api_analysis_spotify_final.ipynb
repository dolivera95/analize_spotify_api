# %% [markdown]
# # Analizar Mi Spotify
# Se va realizar un análisis de mi cuenta de Spotify, donde se tratará de revisar:
# 1. Mis 25 artistas favoritos (más escuchados)
# 1. Las canciones más populares de mis artistas favoritos
# 1. Las canciones con mayor duración de mis artistas favoritos
# 1. La cantidad de albumes de mis artistas favoritos
# 1. La cantidad de singles de mis artistas favoritos
# 1. Los albumes más populares de mis artistas favoritos
# 1. Los albumes con mayor duración de mis artistas favoritos
# 1. Los albumes con mayor cantidad de canciones de mis artistas favoritos

# %% [markdown]
# ## Pasos previos:
# Para poder utilizar el API de spotify se necesita cumplir con ciertos requisitos previos los cuales se pueden encontrar en la documentación de la libreria de Spotipy: https://spotipy.readthedocs.io/en/2.24.0/#getting-started.
# Una vez obtenido el client_id y el client_secret los almaceno en unos files (.client_id y .client_secret) para leerlos para el uso del proyecto

# %% [markdown]
# ## Importaciones de librerias

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd
from datetime import datetime
import os
import time

# %%
# Eliminar el archivo de caché
if os.path.exists('.cache'):
    os.remove('.cache')

# %% [markdown]
# ## Extraccion

# %% [markdown]
# ### Extraer: Consultar los para la conexión del API
# Obtener los parámetros para conectarse al API de Spotify

# %%
# Mi client ID obtenido previamente y guardado en un archivo .client_id
client_id = open('.client_id','r')
client_id = client_id.read()

# %%
# Mi client Secret obtenido previamente y guardado en un archivo .client_secret
client_secret = open('.client_secret','r')
client_secret = client_secret.read()

# %%
# Configuración de la autenticación
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id=client_id,
    client_secret=client_secret,
    redirect_uri='http://localhost:3000',
    scope="user-top-read"
))

# %% [markdown]
# ### Extraer: Mis artistas favoritos
# Obtener un dataframe de los 50 artistas que más escucho

# %%
res_user_top_artists = sp.current_user_top_artists(limit=30, time_range='long_term')

# %%
list_user_top_artists_extract = []
for artist in enumerate(res_user_top_artists['items']):
    id_artist = artist[1]['id']
    name_artist = artist[1]['name']
    q_followers = artist[1]['followers']['total']
    popularity = artist[1]['popularity']
    list_user_top_artists_extract.append(
        [
            id_artist,
            name_artist,
            q_followers,
            popularity
        ]
    )

# %%
df_user_top_artists_extract = pd.DataFrame(list_user_top_artists_extract, columns = ['id_artist', 'name_artist', 'q_followers', 'popularity'])

# %%
df_user_top_artists_extract['extract_datetime'] = datetime.now()

# %%
df_user_top_artists_extract.to_csv('fuente/extraccion/user_top_artists.csv', sep='|', index=False)

# %%
df_user_top_artists_extract.to_excel('fuente/extraccion/user_top_artists.xlsx', index=False)

# %% [markdown]
# ### Extraer: Los albumes de las canciones más populares de mis artistas favoritos
# Obtener un dataframe de los albumes de las canciones más popualares de mis artistas favoritos

# %%
list_top_albums_fav_artists_extract = []
list_genres_albums_extract = []
dict_album = {}
# list_unique_id_albums = df_top_tracks_fav_artists_extract['id_album'].unique()
list_unique_id_albums_artists = df_top_tracks_fav_artists_extract[['id_album', 'id_artist']].drop_duplicates()
#for id_album in list_unique_id_albums:
for index, row in list_unique_id_albums_artists.iterrows():
    time.sleep(1)
    dict_album = sp.album(row['id_album'], 'US')
    total_tracks_album = dict_album['total_tracks']
    id_album = dict_album['id']
    name_album = dict_album['name']
    release_date_album = dict_album['release_date']
    type_album = dict_album['album_type']
    #id_artist = dict_album['artists'][0]['id']
    id_artist = row['id_artist']
    name_artist = dict_album['artists'][0]['name']
    duration_ms_total_album = 0
    populariy_album = dict_album['popularity']
    
    list_tracks_album = dict_album['tracks']['items']
    for track in list_tracks_album:
        duration_ms_total_album = duration_ms_total_album + int(track['duration_ms'])
    list_top_albums_fav_artists_extract.append(
        [
            id_album
            ,id_artist
            ,name_album
            ,type_album
            ,total_tracks_album
            ,release_date_album
            ,duration_ms_total_album
            ,populariy_album
        ]     
    )
    
print("CONSULTA EXITOSA")
# Out:
# CONSULTA EXITOSA

# %%
df_top_albums_fav_artists_extract = pd.DataFrame(list_top_albums_fav_artists_extract, columns = [
            'id_album'
            , 'id_artist'
            , 'name_album'
            , 'type_album'
            , 'total_tracks_album'
            , 'release_date_album'
            , 'duration_ms_total_album'
            , 'populariy_album'
])

# %%
df_top_albums_fav_artists_extract['extract_datetime'] = datetime.now()

# %%
df_top_albums_fav_artists_extract.to_csv('fuente/extraccion/top_albums_fav_artists.csv', sep='|', index=False)

# %%
df_top_albums_fav_artists_extract.to_excel('fuente/extraccion/top_albums_fav_artists.xlsx', index=False)

# %% [markdown]
# ### Todos los Albumnes de mis artistas favoritos

# %%
list_tracks_album = []
list_total_albums_albums = []
#Iteración de artistas
for index, row in df_user_top_artists_extract.iterrows():
    print("///////////////////////////////////")
    print(row['name_artist'])
    id_artist = row['id_artist']
    limit = 50
    offset = 0
    country = 'US'
    include_groups= 'album'
    #Iteración de paginación de albumes del artista
    while True:
        results = sp.artist_albums(id_artist, country=country, include_groups=include_groups,limit=limit, offset=offset)
        #Iteración de los albumnes del artista
        for item in enumerate(results['items']):
            # Pausa para manejar límites de tasa
            time.sleep(1)
            item = item[1]
            type_album = item['album_type']
            total_tracks_album = item['total_tracks']
            id_album = item['id']
            name_album = item['name']
            release_date_album = item['release_date']
            print("\t" + name_album + "\t" + type_album)
            #Más informacion del album
            dict_album = sp.album(id_album, 'US')
            popularity_album = dict_album['popularity']
            duration_ms_total_album = 0            
            list_tracks_album = dict_album['tracks']['items']
            for track in list_tracks_album:
                duration_ms_total_album = duration_ms_total_album + int(track['duration_ms'])       
            list_total_albums_albums.append(
                [
                    id_album
                    , id_artist
                    , name_album
                    , type_album
                    , popularity_album
                    , total_tracks_album
                    , release_date_album
                    , duration_ms_total_album
                ]
            )
        if len(results['items']) < limit:
            break
        offset = offset + limit
        
        # Pausa para manejar límites de tasa
        time.sleep(1)
        
print("Consulta exitosa")
# Out:
# ///////////////////////////////////
# Gorillaz
# 	Cracker Island (Deluxe)	album
# 	Cracker Island	album
# 	Song Machine, Season One: Strange Timez (Deluxe)	album
# 	The Now Now	album
# 	Humanz (Deluxe)	album
# 	Demon Days Live at the Manchester Opera House	album
# 	Plastic Beach	album
# 	The Fall	album
# 	D-Sides [Special Edition]	album
# 	D-Sides	album
# 	Demon Days	album
# 	Laika Come Home	album
# 	Gorillaz	album
# ///////////////////////////////////
# Proleter
# 	Fairuz	album
# 	Rookie (Remastered)	album
# 	Feeding The Lions (Remastered)	album
# 	Curses From Past Times (Remastered)	album
# ///////////////////////////////////
# The Weeknd
# 	Starboy (Deluxe)	album
# 	Live At SoFi Stadium	album
# 	Dawn FM (Alternate World)	album
# 	Dawn FM	album
# 	After Hours (Deluxe)	album
# 	After Hours	album
# 	My Dear Melancholy,	album
# 	Starboy	album
# 	Beauty Behind The Madness	album
# 	Kiss Land (Deluxe)	album
# 	Kiss Land	album
# 	Trilogy	album
# 	Echoes Of Silence (Original)	album
# 	Thursday (Original)	album
# 	House Of Balloons (Original)	album
# ///////////////////////////////////
# League of Legends
# 	Inkborn Fables (Original Soundtrack from Teamfight Tactics Set 11)	album
# 	REMIX RUMBLE (Original Soundtrack from Teamfight Tactics Set 10)	album
# 	Runeterra Reforged (Original Soundtrack)	album
# 	CONVERGENCE: A League of Legends Story (Original Soundtrack)	album
# 	The Mageseeker: A League of Legends Story (Official Soundtrack)	album
# 	Sessions: Star Guardian Taliyah	album
# 	Sessions: Diana	album
# 	Arcane League of Legends (Soundtrack from the Animated Series)	album
# 	Arcane League of Legends (Original Score from Act 3 of the Animated Series)	album
# 	Arcane League of Legends (Original Score from Act 2 of the Animated Series)	album
# 	Arcane League of Legends (Original Score from Act 1 of the Animated Series)	album
# 	Echoes of Light	album
# 	Sessions: Vi	album
# 	The Music of League of Legends: Season 9 (Original Game Soundtrack)	album
# 	The Music of League of Legends: Season 8 (Original Game Soundtrack)	album
# 	The Music of League of Legends: Season 7 (Original Game Soundtrack)	album
# 	The Music of League of Legends: Season 6 (Original Game Soundtrack)	album
# 	The Music of League of Legends: Season 5 (Original Game Soundtrack)	album
# 	The Music of League of Legends: Season 4 (Original Game Soundtrack)	album
# 	The Music of League of Legends: Season 3 (Original Game Soundtrack)	album
# 	The Music of League of Legends: Season 2 (Original Game Soundtrack)	album
# 	The Music of League of Legends: Season 1 (Original Game Soundtrack)	album
# 	Warsongs	album
# 	The Music of League of Legends Vol. 1	album
# ///////////////////////////////////
# Skrillex
# 	Don’t Get Too Close	album
# 	Quest For Fire	album
# 	Skrillex and Diplo present Jack Ü	album
# 	Recess	album
# 	Scary Monsters and Nice Sprites (Deluxe Tour Edition)	album
# ///////////////////////////////////
# Daft Punk
# 	Random Access Memories (Drumless Edition)	album
# 	Random Access Memories (10th Anniversary Edition)	album
# 	Random Access Memories	album
# 	Daft Punk | Random Access Memories | The Collaborators	album
# 	TRON: Legacy Reconfigured	album
# 	TRON: Legacy - The Complete Edition (Original Motion Picture Soundtrack)	album
# 	TRON: Legacy	album
# 	Alive 2007	album
# 	Human After All (Remixes)	album
# 	Human After All	album
# 	Daft Club	album
# 	Alive 1997	album
# 	Discovery	album
# 	Homework (25th Anniversary Edition)	album
# 	Homework	album
# ///////////////////////////////////
# Nirvana
# 	In Utero (30th Anniversary Super Deluxe)	album
# 	Nevermind (30th Anniversary Super Deluxe)	album
# 	Live And Loud	album
# 	Live At The Paramount	album
# 	Live at Reading	album
# 	From The Muddy Banks Of The Wishkah (Live)	album
# 	MTV Unplugged In New York (25th Anniversary)	album
# 	MTV Unplugged In New York	album
# 	In Utero (Super Deluxe Edition)	album
# 	In Utero (Deluxe Edition)	album
# 	In Utero	album
# 	Incesticide	album
# 	Nevermind (Super Deluxe Edition)	album
# 	Nevermind (Remastered)	album
# 	Nevermind (Deluxe Edition)	album
# 	Bleach (Deluxe Edition)	album
# 	Bleach	album
# ///////////////////////////////////
# De Hofnar
# 	Kings And Queens	album
# ///////////////////////////////////
# Florence + The Machine
# 	Dance Fever (Complete Edition)	album
# 	Dance Fever (Live At Madison Square Garden)	album
# 	Dance Fever (Deluxe)	album
# 	Dance Fever	album
# 	High As Hope	album
# 	How Big, How Blue, How Beautiful (Deluxe)	album
# 	MTV Presents Unplugged: Florence + The Machine	album
# 	Ceremonials (Original Deluxe Version)	album
# 	Ceremonials	album
# 	Between Two Lungs	album
# 	Lungs (10th Anniversary Edition)	album
# 	Lungs (International Version)	album
# 	Lungs (Deluxe Version)	album
# ///////////////////////////////////
# Metro Boomin
# 	WE STILL DON'T TRUST YOU	album
# 	WE DON'T TRUST YOU	album
# 	METRO BOOMIN PRESENTS SPIDER-MAN: ACROSS THE SPIDER-VERSE [SOUNDTRACK FROM AND INSPIRED BY THE MOTION PICTURE (METROVERSE INSTRUMENTAL EDITION)]	album
# 	METRO BOOMIN PRESENTS SPIDER-MAN: ACROSS THE SPIDER-VERSE (SOUNDTRACK FROM AND INSPIRED BY THE MOTION PICTURE / DELUXE EDITION)	album
# 	METRO BOOMIN PRESENTS SPIDER-MAN: ACROSS THE SPIDER-VERSE (SOUNDTRACK FROM AND INSPIRED BY THE MOTION PICTURE)	album
# 	HEROES & VILLAINS (Villains Version)	album
# 	HEROES & VILLAINS (Heroes Version)	album
# 	HEROES & VILLAINS	album
# 	SAVAGE MODE II [CHOPPED NOT SLOPPED]	album
# 	SAVAGE MODE II	album
# 	NOT ALL HEROES WEAR CAPES (Deluxe)	album
# 	Double Or Nothing (& Metro Boomin)	album
# 	Without Warning	album
# 	Perfect Timing	album
# 	Savage Mode	album
# 	19 & Boomin	album
# ///////////////////////////////////
# El Cuarteto De Nos
# 	Lámina Once	album
# 	Jueves	album
# 	Apocalipsis Zombi	album
# 	Habla Tu Espejo	album
# 	Porfiado	album
# 	Bipolar	album
# 	Raro	album
# 	Cortamambo	album
# 	Revista ¡Ésta!	album
# 	El Tren Bala	album
# 	Barranca Abajo	album
# 	Otra navidad en las trincheras	album
# 	Canciones del Corazón	album
# 	Emilio García	album
# 	Soy una Arveja	album
# 	Alberto Wolf y el Cuarteto de Nos	album
# ///////////////////////////////////
# Galantis
# 	Rx	album
# 	Church	album
# 	The Aviary	album
# 	Pharmacy	album
# ///////////////////////////////////
# Eminem
# 	The Death of Slim Shady (Coup De Grâce)	album
# 	The Marshall Mathers LP2 (Expanded Edition)	album
# 	Curtain Call 2	album
# 	The Eminem Show (Expanded Edition)	album
# 	Music To Be Murdered By - Side B (Deluxe Edition)	album
# 	Music To Be Murdered By	album
# 	Kamikaze	album
# 	Revival	album
# 	The Marshall Mathers LP2 (Deluxe)	album
# 	Recovery (Deluxe Edition)	album
# 	Recovery	album
# 	Relapse: Refill	album
# 	Relapse [Deluxe]	album
# 	Relapse	album
# 	Encore (Deluxe Version)	album
# 	The Eminem Show	album
# 	The Marshall Mathers LP	album
# 	The Slim Shady LP (Expanded Edition)	album
# 	The Slim Shady LP	album
# ///////////////////////////////////
# K/DA
# ///////////////////////////////////
# Die Antwoord
# 	HOUSE OF ZEF	album
# 	MADE BY GOD (Chapter III)	album
# 	MADE BY GOD (Chapter II)	album
# 	MADE BY GOD (Chapter I)	album
# 	Mount Ninji And Da Nice Time Kid	album
# 	SUCK ON THIS (MIXTAPE)	album
# 	Donker Mag	album
# 	Ten$ion	album
# 	$O$ (International Deluxe Version)	album
# 	$O$	album
# ///////////////////////////////////
# Red Hot Chili Peppers
# 	Return of the Dream Canteen	album
# 	Unlimited Love	album
# 	The Getaway	album
# 	I'm with You	album
# 	Stadium Arcadium	album
# 	By the Way (Deluxe Edition)	album
# 	By the Way	album
# 	Californication (Deluxe Edition)	album
# 	Californication	album
# 	One Hot Minute (Deluxe Edition)	album
# 	One Hot Minute	album
# 	Blood Sugar Sex Magik (Deluxe Edition)	album
# 	Mother's Milk	album
# 	The Uplift Mofo Party Plan	album
# 	Freaky Styley	album
# 	Red Hot Chili Peppers	album
# ///////////////////////////////////
# Jacob Tillberg
# ///////////////////////////////////
# Linkin Park
# 	Papercuts: Instrumentals	album
# 	Papercuts	album
# 	Meteora 20th Anniversary Edition	album
# 	Hybrid Theory (20th Anniversary Edition)	album
# 	One More Light Live	album
# 	One More Light	album
# 	The Hunting Party: Acapellas + Instrumentals	album
# 	The Hunting Party	album
# 	RECHARGED	album
# 	LIVING THINGS: Acapellas and Instrumentals	album
# 	LIVING THINGS	album
# 	A Thousand Suns Live Around the World	album
# 	Minutes to Midnight Live Around the World	album
# 	Meteora Live Around the World	album
# 	Hybrid Theory Live Around the World	album
# 	A Thousand Suns (Bonus Edition)	album
# 	A Thousand Suns	album
# 	Road to Revolution (Live at Milton Keynes)	album
# 	Minutes to Midnight (Deluxe Edition)	album
# 	Minutes to Midnight	album
# 	Live in Texas	album
# 	Meteora (Bonus Edition)	album
# 	Reanimation	album
# 	Hybrid Theory (Bonus Edition)	album
# ///////////////////////////////////
# VALORANT
# 	MV//MNT VOL. 02	album
# 	MV//MNT	album
# ///////////////////////////////////
# Pendulum
# 	The Reworks	album
# 	Immersion	album
# 	Live at Brixton Academy	album
# 	In Silico	album
# 	Hold Your Colour (Deluxe)	album
# 	Hold Your Colour	album
# ///////////////////////////////////
# Knife Party
# 	Abandon Ship	album
# ///////////////////////////////////
# Bad Bunny
# 	nadie sabe lo que va a pasar mañana	album
# 	Un Verano Sin Ti	album
# 	EL ÚLTIMO TOUR DEL MUNDO	album
# 	LAS QUE NO IBAN A SALIR	album
# 	YHLQMDLG	album
# 	OASIS	album
# 	X 100PRE	album
# ///////////////////////////////////
# Anuel AA
# 	LLNM2	album
# 	Las Leyendas Nunca Mueren	album
# 	Los Dioses	album
# 	Emmanuel	album
# 	Real Hasta la Muerte	album
# ///////////////////////////////////
# M|O|O|N
# 	Come! See!!	album
# 	Demos 2014-2017	album
# 	Clinically Blasé	album
# ///////////////////////////////////
# La Mente
# 	Millonarios del Alma	album
# 	PLAYLIZT Presenta: la Mente (En Vivo)	album
# 	Sonidos del Sistema	album
# 	Música	album
# 	Para los Muertos y los Vivientes (Sonidos del Sistema)	album
# 	Sonidos del Sistema: Electropical	album
# ///////////////////////////////////
# Three Days Grace
# 	EXPLOSIONS	album
# 	Outsider	album
# 	Human	album
# 	Transit Of Venus	album
# 	Life Starts Now	album
# 	One-X	album
# 	Three Days Grace (Expanded Edition)	album
# 	Three Days Grace	album
# ///////////////////////////////////
# Fadex
# 	Hi Rain	album
# 	Trip	album
# ///////////////////////////////////
# La Nueva Invasión
# 	Amor y Resistencia	album
# 	Vitamina Inka	album
# 	Súbele a la Radio	album
# ///////////////////////////////////
# Avicii
# 	TIM	album
# 	Stories	album
# 	True: Avicii By Avicii	album
# 	The Days / Nights	album
# 	True (Bonus Edition)	album
# 	True	album
# ///////////////////////////////////
# Pitbull
# 	Trackhouse (Daytona 500 Edition)	album
# 	Trackhouse	album
# 	Libertad 548	album
# 	Gotti (Original Motion Picture Soundtrack)	album
# 	Climate Change	album
# 	Dale	album
# 	Globalization	album
# 	Global Warming: Meltdown (Deluxe Version)	album
# 	Planet Pit (Deluxe Version)	album
# 	Planet Pit	album
# 	Armando (Deluxe)	album
# 	I Am Armando - Armando Reloaded	album
# 	Pitbull Starring In Rebelution	album
# 	The Boatlift - Clean	album
# 	The Boatlift	album
# 	El Mariel - Clean	album
# 	El Mariel	album
# 	Money Is Still A Major Issue	album
# 	M.I.A.M.I.	album
# Consulta exitosa

# %%
list_tracks_album = []
list_total_singles_albums = []
#Iteración de artistas
for index, row in df_user_top_artists_extract.iterrows():
    print("///////////////////////////////////")
    print(row['name_artist'])
    id_artist = row['id_artist']
    limit = 50
    offset = 0
    country = 'US'
    include_groups= 'single'
    #Iteración de paginación de albumes del artista
    while True:
        results = sp.artist_albums(id_artist, country=country, include_groups=include_groups, limit=limit, offset=offset)
        #Iteración de los albumnes del artista
        for item in enumerate(results['items']):
            # Pausa para manejar límites de tasa
            time.sleep(1)
            item = item[1]
            type_album = item['album_type']
            total_tracks_album = item['total_tracks']
            id_album = item['id']
            name_album = item['name']
            release_date_album = item['release_date']
            print("\t" + name_album + "\t" + type_album)
            #Más informacion del album
            dict_album = sp.album(id_album, 'US')
            popularity_album = dict_album['popularity']
            duration_ms_total_album = 0            
            list_tracks_album = dict_album['tracks']['items']
            for track in list_tracks_album:
                duration_ms_total_album = duration_ms_total_album + int(track['duration_ms'])       
            list_total_singles_albums.append(
                [
                    id_album
                    , id_artist
                    , name_album
                    , type_album
                    , popularity_album
                    , total_tracks_album
                    , release_date_album
                    , duration_ms_total_album
                ]
            )
        if len(results['items']) < limit:
            break
        offset = offset + limit
        
        # Pausa para manejar límites de tasa
        time.sleep(1)
        
print("Consulta exitosa")
# Out:
# ///////////////////////////////////
# Gorillaz
# 	New Gold (feat. Tame Impala and Bootie Brown) [Dom Dolla Remix]	single
# 	Baby Queen	single
# 	New Gold (feat. Tame Impala and Bootie Brown)	single
# 	Cracker Island (feat. Thundercat)	single
# 	Meanwhile EP	single
# 	The Now Now (Gorillaz 20 Mix)	single
# 	Demon Days (Gorillaz 20 Mix)	single
# 	Humanz (Gorillaz 20 Mix)	single
# 	Gorillaz (Gorillaz 20 Mix)	single
# 	Song Machine Episode 8	single
# 	Song Machine, Season One: Strange Timez (Gorillaz 20 Mix)	single
# 	Mud’z Massive Machine Mix	single
# 	Russel Hobbs Presents a Flamin' Hot Song Machine Mix	single
# 	Song Machine Made by 2D From Gorillaz	single
# 	The Machine Is On!! A Song Machine Mix by Noodle	single
# 	Song Machine Episode 7	single
# 	Song Machine Episode 6	single
# 	Song Machine Episode 5	single
# 	Song Machine Episode 4	single
# 	How Far? (feat. Tony Allen and Skepta)	single
# 	Song Machine Episode 3	single
# 	Song Machine Episode 2	single
# 	Song Machine Episode 1	single
# 	Song Machine Theme Tune	single
# 	Tranz (Poté Remix)	single
# 	Tranz	single
# 	Humility (feat. George Benson) [Remixes]	single
# 	Hollywood (feat. Snoop Dogg & Jamie Principle)	single
# 	Fire Flies	single
# 	Sorcererz	single
# 	Lake Zurich	single
# 	Humility (feat. George Benson)	single
# 	Andromeda (DRAM Special)	single
# 	Garage Palace (feat. Little Simz)	single
# 	Busted and Blue (Yotto Remix)	single
# 	Saturnz Barz (feat. Popcaan, Assassin, Mad Cobra, Teddy Bruckshot & Killa P) [Cadenza Remix]	single
# 	Strobelite (feat. Peven Everett) [Kaytranada Remix]	single
# 	Strobelite (feat. Peven Everett) [Radio Edit]	single
# 	Sleeping Powder	single
# 	The Apprentice (feat. Rag'n'Bone Man, Zebra Katz & RAY BLK)	single
# 	Saturnz Barz (feat. Popcaan) [Baauer Remix]	single
# 	Let Me Out (feat. Mavis Staples & Pusha T) [Banx & Ranx Remix]	single
# 	Andromeda (feat. D.R.A.M.) [ZHU Remix]	single
# 	Andromeda (feat. D.R.A.M.) [Purple Disco Machine Remix]	single
# 	We Got the Power (feat. Jehnny Beth) [Claptone Remix]	single
# 	Saturnz Barz (feat. Popcaan) [Banx & Ranx Remix]	single
# 	Ascension (feat. Vince Staples) [Nic Fanciulli Remix]	single
# 	Andromeda (feat. D.R.A.M.) [Bonobo Remix]	single
# 	Let Me Out (feat. Mavis Staples & Pusha T)	single
# 	Saturnz Barz (feat. Popcaan)	single
# 	We Got the Power (feat. Jehnny Beth)	single
# 	Ascension (feat. Vince Staples)	single
# 	Andromeda (feat. D.R.A.M.)	single
# 	911 [Live in NYC] (feat. D12) [Live in NYC;feat. D12]	single
# 	Doncamatic (feat. Daley) [The Joker Remix]	single
# 	Stylo (feat. Mos Def and Bobby Womack)	single
# 	Feel Good Inc.	single
# 	DARE	single
# 	El Mañana / Kids with Guns	single
# 	Dirty Harry	single
# 	Dirty Harry	single
# 	DARE	single
# 	Feel Good Inc. (Instrumental)	single
# 	Lil' Dub Chefin'	single
# 	Clint Eastwood	single
# ///////////////////////////////////
# Proleter
# 	Moonswings	single
# 	Sunny Summer	single
# 	Javelins	single
# 	PLEINS PHARES (Proleter Remix - Electro Swing)	single
# 	Folklore	single
# 	April Showers (The Platinum EP)	single
# 	The Maze in My Mind	single
# 	The Last Breath of My Soul	single
# 	Lady Vengeance	single
# 	Chasing the Clouds	single
# 	Spirit-Inside (ProleteR Remix)	single
# 	All Right ! (Cdc08)	single
# 	Trust In Me	single
# 	November in Paris	single
# 	March Winds & April Showers	single
# 	Mars en jazz (ProleteR Remix)	single
# 	Chicago (Proleter Remix)	single
# 	Everyday People	single
# 	Bubbles	single
# 	What Lana Says	single
# 	Miss Her	single
# 	April Showers (feat. Natey G)	single
# 	Life Playing Tricks	single
# 	Alone After All	single
# 	Destiny	single
# 	L.O.V.E	single
# 	Rookie	single
# 	Feeding the Lions	single
# 	Curses From Past Times	single
# ///////////////////////////////////
# The Weeknd
# 	Popular	single
# 	One of the Girls	single
# 	Another One Of Me (feat. 21 Savage)	single
# 	K-POP	single
# 	K-POP (Chopped & Screwed)	single
# 	The Idol Episode 5 Part 2 (Music from the HBO Original Series)	single
# 	The Idol Episode 5 Part 1 (Music from the HBO Original Series)	single
# 	The Idol Episode 4 (Music from the HBO Original Series)	single
# 	The Idol Episode 3 (Music from the HBO Original Series)	single
# 	The Idol Episode 2 (Music from the HBO Original Series)	single
# 	The Idol Episode 1 (Music from the HBO Original Series)	single
# 	Popular (Music from the HBO Original Series)	single
# 	Double Fantasy	single
# 	Creepin' (Remix)	single
# 	Die For You	single
# 	Die For You (Remix)	single
# 	Best Friends (Remix)	single
# 	How Do I Make You Love Me? (Sebastian Ingrosso & Salvatore Ganacci Remix)	single
# 	Dawn FM (OPN Remix)	single
# 	Starry Eyes (MIKE DEAN Remix)	single
# 	Out Of Time (Remix Bundle)	single
# 	Moth To A Flame (Moojo Remix)	single
# 	Moth To A Flame	single
# 	One Right Now	single
# 	Hurricane	single
# 	Die For It (ft. Nas)	single
# 	Take My Breath	single
# 	Take My Breath	single
# 	Better Believe	single
# 	You Right	single
# 	Save Your Tears (Remix)	single
# 	Blinding Lights (Remix)	single
# 	Christmas Blues (with The Weeknd)	single
# 	Hawái (Remix)	single
# 	In Your Eyes (Remix)	single
# 	King Of The Fall	single
# 	Blinding Lights (Instrumental)	single
# 	Blinding Lights	single
# 	Over Now (with The Weeknd)	single
# 	Smile (with The Weeknd)	single
# 	In Your Eyes (Remix)	single
# 	After Hours (Remixes)	single
# 	Blinding Lights (Major Lazer Remix)	single
# 	Reminder (Remix)	single
# 	Lust for Life (with The Weeknd)	single
# 	Starboy (Kygo Remix)	single
# 	The Hills (RL Grime Remix)	single
# 	Can't Feel My Face (Martin Garrix Remix)	single
# 	The Hills Remixes	single
# 	Often (Kygo Remix)	single
# 	Earned It (Fifty Shades Of Grey) [From The "Fifty Shades Of Grey" Soundtrack]	single
# 	Wanderlust	single
# 	Or Nah (feat. The Weeknd, Wiz Khalifa & DJ Mustard) [Remix]	single
# 	Wanderlust (Remixes)	single
# ///////////////////////////////////
# League of Legends
# 	Hall of Legends: Orchestral Theme	single
# 	Lee Sin, the Blind Monk	single
# 	Skarner, the Primordial Sovereign	single
# 	Mi Clan	single
# 	Rise (Redux)	single
# 	Smolder, the Fiery Fledgling	single
# 	Still Here	single
# 	You & Me Makes Us	single
# 	REMIX RUMBLE	single
# 	Hwei, the Visionary	single
# 	REMIX RUMBLE (Steve Aoki Remix)	single
# 	PARANOIA	single
# 	Jax, the Grandmaster at Arms	single
# 	GODS	single
# 	2023 World Championship Theme	single
# 	Awaken (Re-Jinxed)	single
# 	Feeding Frenzy (Briar Cinematic Score)	single
# 	Briar, the Restrained Hunger (Champion Theme)	single
# 	Orgulho Loco	single
# 	Soul Fighter (Original Soundtrack)	single
# 	Naafiri, the Hound of a Hundred Bites	single
# 	Shine On	single
# 	Inkshadow (Skin Theme)	single
# 	Rules (Are Meant to Break)	single
# 	Faerie Court (Skin Theme)	single
# 	Milio, the Gentle Flame (Champion Theme)	single
# 	Ahri, the Nine-Tailed Fox	single
# 	Lunar Revel 2023 (Event Theme)	single
# 	Winterblessed - 2022 (Skins Theme)	single
# 	Predator (World Ender Remix)	single
# 	Predator (World Ender Remix)	single
# 	Fire to the Fuse	single
# 	K'Sante, the Pride of Nazumah	single
# 	2022 World Championship Theme	single
# 	Awakened	single
# 	Udyr, the Spirit Walker	single
# 	Everything Goes On	single
# 	Nilah, the Joy Unbound	single
# 	Star Guardian 2022 (Official Orchestral Theme)	single
# 	Bel'Veth, the Empress of the Void	single
# 	Set It Off	single
# 	Drop the villain	single
# 	Renata Glasc, the Chem-Baroness	single
# 	Zeri, the Spark of Zaun	single
# 	Porcelain - 2022	single
# 	The Call	single
# 	When Everything Went Wrong (from the series Arcane League of Legends)	single
# 	Guns for Hire (From the series Arcane League of Legends)	single
# 	Dirty Little Animals (From the series Arcane League of Legends)	single
# 	Playground (from the series Arcane League of Legends)	single
# 	Our Love (From the series Arcane League of Legends)	single
# 	Goodbye (from the series Arcane League of Legends)	single
# 	Caitlyn, the Sheriff of Piltover (Piano Arrangement)	single
# 	Caitlyn, the Sheriff of Piltover	single
# 	Enemy (from the series Arcane League of Legends)	single
# 	Dragonmancer - 2021	single
# 	Burn It All Down (Denzel Curry Remix)	single
# 	Burn It All Down (CIFIKA Remix)	single
# 	Burn It All Down (Besomorph Remix)	single
# 	Burn It All Down	single
# 	Vex, the Gloomist	single
# 	2021 World Championship Theme	single
# 	Rebirth	single
# 	Coven - 2021	single
# 	Akshan, the Rogue Sentinel	single
# 	Sentinels of Light - 2021	single
# 	Fate of Demacia	single
# 	Dr. Mundo, the Madman of Zaun	single
# 	PROJECT - 2021	single
# 	Starts Right Here	single
# 	Gwen, the Hallowed Seamstress	single
# 	Space Groove - 2021	single
# 	Lunar Beasts - 2021	single
# 	Viego, the Ruined King	single
# 	Lunar Beats | Club 2 Arena Theme - Teamfight Tactics	single
# 	Run It	single
# 	Rell, the Iron Maiden	single
# 	Battle Queens - 2020	single
# 	Seraphine, the Starry-Eyed Songstress	single
# 	Take Over (ford. Remix)	single
# 	Samira, the Desert Rose	single
# 	Take Over	single
# 	2020 World Championship Theme	single
# 	PsyOps - 2020	single
# 	Yone, the Unforgotten	single
# 	Lillia, the Bashful Bloom	single
# 	Volibear, the Relentless Storm	single
# 	Fiddlesticks, the Harbinger of Doom	single
# 	Sett, the Boss	single
# 	Aphelios, the Weapon of the Faithful	single
# 	Senna, the Redeemer	single
# 	Warriors	single
# 	Start It Up	single
# 	Phoenix (1788-L Remix)	single
# 	Phoenix (Carpenter Brut Remix)	single
# 	Phoenix (Blanke Remix)	single
# 	Phoenix	single
# 	2019 World Championship Theme	single
# 	Bring Home The Glory	single
# 	Awaken	single
# 	Raise Up The Lights (2018 All-Star Event)	single
# 	RISE (Remix)	single
# 	RISE	single
# 	2018 World Championship Theme	single
# 	2017 World Championship Theme	single
# 	2018 Rift Rivals Theme	single
# 	2018 Mid-Season Invitational Theme (feat. Danger)	single
# 	2017 Mid-Season Invitational Theme	single
# 	As We Fall	single
# 	Legends Never Die	single
# 	Burning Bright	single
# 	Bit Rush: Arcade Ahri	single
# 	2016 World Championship Theme	single
# 	2016 Mid-Season Invitational Theme	single
# 	Worlds Collide	single
# 	Bit Rush	single
# 	Welcome to Planet Urf	single
# ///////////////////////////////////
# Skrillex
# 	Push	single
# 	TAKA	single
# 	Pepper	single
# 	Yo Fam!	single
# 	Badders	single
# 	Fine Day Anthem	single
# 	Baby again..	single
# 	Tears	single
# 	TOO BIZARRE (juked)	single
# 	Summertime	single
# 	Still Here (with the ones that I came with)	single
# 	Selecta	single
# 	RATATA	single
# 	Painting Rainbows	single
# 	Mixed Signals	single
# 	Inhale Exhale	single
# 	Hydrate	single
# 	Good Space	single
# 	Don’t Leave Me Like This	single
# 	Ceremony	single
# 	Bad For Me	single
# 	A Street I Know	single
# 	3am	single
# 	Don’t Get Too Close	single
# 	XENA	single
# 	Real Spring	single
# 	Leave Me Like This	single
# 	Way Back	single
# 	Rumble	single
# 	Torture Me (feat. Skrillex)	single
# 	Horizon (with Noisia)	single
# 	Don’t Go (with Justin Bieber & Don Toliver)	single
# 	En Mi Cuarto	single
# 	In Da Getto	single
# 	Supersonic (My Existence) [with Noisia, josh pan & Dylan Brady]	single
# 	Too Bizarre (with Swae Lee & Siiickbrain)	single
# 	Butterflies	single
# 	Midnight Hour with Boys Noize & Ty Dolla $ign (Remixes)	single
# 	Midnight Hour with Boys Noize & Ty Dolla $ign (Four Tet Remix)	single
# 	Midnight Hour with Boys Noize & Ty Dolla $ign	single
# 	Malokera (feat. Ludmilla, Ty Dolla $ign)	single
# 	Show Tracks	single
# 	two nights part ii (Lykke Li x Skrillex x Ty Dolla $ign)	single
# 	Way To Break My Heart (feat. Skrillex)	single
# 	WARLORDZ (feat. Skrillex)	single
# 	Turn Off The Lights	single
# 	Due West (Skrillex Remix)	single
# 	SICKO MODE (Skrillex Remix)	single
# 	AGEN WIDA	single
# 	The Island, Pt. 1 (Dawn) [Skrillex Remix]	single
# 	Goh	single
# 	HUMBLE. (SKRILLEX REMIX)	single
# 	Would You Ever (Conducta Remix)	single
# 	Would You Ever (Branchez & Charlie Klarsfeld Remix)	single
# 	Would You Ever (4B Remix)	single
# 	Deadbeat (feat. Skrillex)	single
# 	Favor	single
# 	Saint Laurent	single
# 	Would You Ever	single
# 	Waiting	single
# 	Slam Dunk	single
# 	Mind (feat. Kai) [Remixes]	single
# 	Purple Lamborghini (with Rick Ross)	single
# 	Killa Remixes	single
# 	No Chill	single
# 	Where Are Ü Now Live (with Justin Bieber)	single
# 	Working For It (Nomero Remix)	single
# 	Stranger (Skrillex Remix with Tennyson & White Sea)	single
# 	To Ü (feat. AlunaGeorge) [Remixes]	single
# 	El Chapo - Single	single
# 	SQUAD OUT! (feat. Fatman Scoop)	single
# 	Bun Up the Dance	single
# 	Burial (feat. Pusha T, Moody Good, TrollPhace)	single
# 	Where Are Ü Now (with Justin Bieber) [Remixes]	single
# 	Take Ü There (feat. Kiesza) [Missy Elliott Remix]	single
# 	Take Ü There (feat. Kiesza) [Remixes]	single
# 	Dirty Vibe (Remixes)	single
# 	Ease My Mind v Ragga Bomb Remixes	single
# 	Take Ü There (feat. Kiesza)	single
# 	Recess Remixes (feat. Fatman Scoop and Michael Angelakos)	single
# 	Try It Out	single
# 	Make It Bun Dem After Hours EP	single
# 	Lick It (Kaz James Remix)	single
# 	Make It Bun Dem	single
# 	Breakn' A Sweat (Zedd Remix)	single
# 	Lick It	single
# 	Bangarang EP	single
# 	More Monsters and Sprites EP	single
# 	Weekends!!! (feat. Sirah)	single
# ///////////////////////////////////
# Daft Punk
# 	Infinity Repeating (2013 Demo) [feat. Julian Casablancas+The Voidz]	single
# 	GLBTM (Studio Outtakes)	single
# 	The Writing of Fragments of Time	single
# 	Get Lucky (Daft Punk Remix) (feat. Pharrell Williams & Nile Rodgers)	single
# 	Get Lucky (Radio Edit) [feat. Pharrell Williams and Nile Rodgers]	single
# 	Technologic (Radio Edit)	single
# 	Robot Rock (Edit)	single
# 	Human After All (Medley)	single
# 	Something About Us (Love Theme from Interstella)	single
# 	Harder, Better, Faster, Stronger (Live)	single
# 	Harder, Better, Faster, Stronger (Alive Radio Edit 2007)	single
# 	Harder, Better, Faster, Stronger	single
# 	Digital Love	single
# 	Aerodynamic	single
# 	One More Time	single
# 	Revolution 909	single
# 	Burnin'	single
# 	Around the World	single
# 	Da Funk	single
# ///////////////////////////////////
# Nirvana
# 	In Utero 30th Live	single
# 	Smells Like Teen Spirit / In Bloom / On A Plain / Lithium / Breed	single
# 	In Bloom / On A Plain / Lithium / Breed	single
# 	On A Plain / Lithium / Breed (Live)	single
# 	Lithium / Breed (Live)	single
# 	Breed (Live In Amsterdam, Netherlands/1991)	single
# ///////////////////////////////////
# De Hofnar
# 	Mamacita	single
# 	I've Been Thinking About You	single
# 	Teardrops (Kid On The Block Remix)	single
# 	One, Two, Three - Boostereo Remix	single
# 	Thousand Pictures	single
# 	If You Had My Love (Kav Verhouzer Remix) [Sped Up]	single
# 	There You Are	single
# 	Never C U Again	single
# 	Radio Love (Extended Mix)	single
# 	Radio Love	single
# 	Teardrops	single
# 	Take Me Home (De Hofnar Remix)	single
# 	Good Times	single
# 	Echo (with AVY X)	single
# 	Another Round (RSCL Remix)	single
# 	Another Round	single
# 	Blindly	single
# 	Dance With Me	single
# 	Downtown	single
# 	Never Leave You (Uh Oooh, Uh Oooh)	single
# 	Don't Stop	single
# 	One, Two, Three	single
# 	The Feeling	single
# 	Don't Mess With My Man	single
# 	All That She Wants	single
# 	If You Had My Love (Kav Verhouzer Remix)	single
# 	Whoops	single
# 	Jealousy	single
# 	Sexy	single
# 	Morning Sun	single
# 	Ego	single
# 	Follow You (De Hofnar Remix)	single
# 	If You Had My Love	single
# 	Stacey	single
# 	Touch Di Road	single
# 	Whatever I Like	single
# 	It's Over (Tom Ferry Remix)	single
# 	No One Else	single
# 	It's Over	single
# 	Wereldbol	single
# 	Do It Again (feat. Jantine)	single
# 	Liquid Cocaine	single
# 	Restart	single
# 	Kings and Queens, Pt. 2	single
# 	Wasted	single
# 	Goin' Down	single
# 	Moving On	single
# 	Moments (Remixes - EP2)	single
# 	Kings and Queens	single
# 	In Too Deep	single
# 	Outrun	single
# 	Breakup Song	single
# 	Little Love (Redondo Remix)	single
# 	Little Love	single
# 	Kings and Queens	single
# 	Superstar	single
# 	Fireburn	single
# 	Your Skin (De Hofnar Remix)	single
# 	Superstar	single
# 	Falling In Love (De Hofnar Remix)	single
# 	Mystery Repeats (De Hofnar Remix)	single
# 	Forget Who We Are	single
# 	Back In The Day	single
# 	Lethal Industry (De Hofnar & The Techtives Remix)	single
# 	Crazy Love (Original Mix)	single
# 	Bloesem	single
# 	Oxas	single
# 	Zonnestraal	single
# ///////////////////////////////////
# Florence + The Machine
# 	Mermaids	single
# 	Just A Girl (From The Original Series “Yellowjackets”)	single
# 	Morning Elvis (Live At Denver Ball Arena)	single
# 	Heaven Is Here (IDLES Remix)	single
# 	Dance Fever (Poem Versions)	single
# 	Free (The Blessed Madonna Remix)	single
# 	Free	single
# 	My Love (MEDUZA Remix)	single
# 	My Love (Dave Glass Animals Remix)	single
# 	My Love	single
# 	Heaven Is Here	single
# 	King	single
# 	Light Of Love	single
# 	My Best Dress (Demo)	single
# 	Donkey Kosh (Demo)	single
# 	Jenny of Oldstones (Game of Thrones)	single
# 	Moderation	single
# 	Spotify Singles	single
# 	Patricia (Acoustic)	single
# 	Big God	single
# 	Hunger	single
# 	Sky Full Of Song	single
# 	Wish That You Were Here (From “Miss Peregrine’s Home For Peculiar Children” Original Motion Picture Soundtrack)	single
# 	Songs From Final Fantasy XV	single
# 	I Love You All the Time (Play It Forward Campaign) [feat. The Maccabees]	single
# 	Delilah (Galantis Remix / Edit)	single
# 	Delilah (Radio Edit)	single
# 	Queen Of Peace (Hot Chip Remix)	single
# 	Queen Of Peace (Radio Edit)	single
# 	What Kind Of Man (Nicolas Jaar Remix)	single
# 	Lover To Lover (Ceremonials Tour Version)	single
# 	What The Water Gave Me	single
# 	Shake It Out	single
# 	You've Got The Love	single
# 	Heavy In Your Arms	single
# 	You've Got The Love (Jamie xx Rework)	single
# 	A Lot of Love. a Lot of Blood	single
# 	Dog Days Are Over	single
# 	Kiss With A Fist	single
# ///////////////////////////////////
# Metro Boomin
# 	pop ur shit	single
# 	née-nah	single
# 	just like me	single
# 	dangerous	single
# 	Creepin' (Remix)	single
# 	Intro I 2020 (Only 1 Remix)	single
# 	Blue Pill	single
# 	Perfect Timing (Intro)	single
# 	Call Me	single
# 	Chanel Vintage (feat. Future & Young Thug) - Single	single
# 	Chanel Vintage (feat. Future & Young Thug) - Single	single
# ///////////////////////////////////
# El Cuarteto De Nos
# 	Chivo Expiatorio (En Vivo)	single
# 	El Cinturón Gris (En Vivo)	single
# 	Rorschach	single
# 	Maldito Show	single
# 	La Ciudad Sin Alma	single
# 	Fiesta en lo del Dr. Hermes (En Vivo)	single
# 	Fiesta en lo del Dr. Hermes	single
# 	Contrapunto para Humano y Computadora	single
# 	Punta Cana	single
# 	Gaucho Power	single
# 	No Llora	single
# 	Cuando sea grande	single
# ///////////////////////////////////
# Galantis
# 	One Cry (Galantis & Misha K VIP Mix)	single
# 	Pretty Low	single
# 	Pride Pack	single
# 	One Cry (feat. Rosa Linn)	single
# 	Mountains	single
# 	Dust	single
# 	Universe (Galantis Remix)	single
# 	Lighter (MY PAL AL Remix)	single
# 	Lighter (Galantis & Misha K VIP Mix)	single
# 	Lighter	single
# 	One, Two, & 3	single
# 	Lighter (Extended Mix)	single
# 	Little Bit Yours (Remixes)	single
# 	Gold Dust (ILLENIUM 2015 Remix)	single
# 	Very Important Remixes	single
# 	Lil Boo Thang (Galantis Remix)	single
# 	Little Bit Yours	single
# 	Dreamteam	single
# 	Koala (LOSTBOYJAY Remix)	single
# 	Koala (secs on the beach Remix)	single
# 	Koala (Galantis & Misha K VIP Mix)	single
# 	Koala	single
# 	BANG BANG! (My Neurodivergent Anthem) [Galantis & Misha K VIP Mix]	single
# 	BANG BANG! (My Neurodivergent Anthem)	single
# 	Fool 4 U (feat. JVKE & Enisa) [VIP Mix]	single
# 	Fool 4 U (feat. Enisa)	single
# 	Damn (You’ve Got Me Saying) [East & Young Remix]	single
# 	Hungry Heart ft. Hayley Kiyoko	single
# 	Sped Up/Slowed Down Versions	single
# 	I Want You	single
# 	Moneymaker (Galantis & secs on the beach Remix)	single
# 	Hooked (Hot Stuff)	single
# 	Believe (feat. Goodboys) [Galantis Remix]	single
# 	Damn (You’ve Got Me Saying) [Galantis & Misha K VIP Mix]	single
# 	Damn (You’ve Got Me Saying)	single
# 	DNA (Sam Feldt Remix)	single
# 	Runaway (U & I) [Subtronics Remix]	single
# 	DNA (Part 2)	single
# 	Left and Right (feat. Jung Kook of BTS) [Galantis Remix]	single
# 	DNA	single
# 	What It Feels Like (Navos VIP Remix)	single
# 	What It Feels Like (Tita Lau Remix)	single
# 	what would you do? (Galantis Remix)	single
# 	Run (Sam Feldt Remix)	single
# 	1x1	single
# 	Run (Melé Remix)	single
# 	Good Luck (D.O.D Remix)	single
# 	Good Luck (Acoustic)	single
# 	Fading Like A Flower	single
# 	What It Feels Like	single
# 	Run (Acoustic)	single
# 	Run (Galantis & Misha K VIP Mix)	single
# 	Good Luck	single
# 	Sweet Talker (Hot Since 82 Remix)	single
# 	Run	single
# 	When The Lights Go Down (feat. Cody Simpson)	single
# 	Sweet Talker (Navos Remix)	single
# 	Alien (Extended Mix)	single
# 	Alien	single
# 	Sweet Talker	single
# 	My Universe (Galantis Remix)	single
# 	The Best (Remixes)	single
# 	The Best (Toby Romeo Remix)	single
# 	Heartbreak Anthem (with David Guetta & Little Mix) [Remixes]	single
# 	Heartbreak Anthem (with David Guetta & Little Mix) [Clean Bandit Remix]	single
# 	Tears For Later	single
# 	Heartbreak Anthem (with David Guetta & Little Mix) [Tchami Remix]	single
# 	Die For a Man (feat. Lil Uzi Vert) [Galantis Remix]	single
# 	Buenos Aires (Galantis x Bali Bandits Remix)	single
# 	Retrograde (Galantis Remix)	single
# 	Heartbreak Anthem (with David Guetta & Little Mix)	single
# 	The Best	single
# 	Dandelion (Remixes)	single
# 	Dandelion	single
# 	Acredita No Véio (Listen to the Old Man) (Galantis Version)	single
# 	Tu Tu Tu (That's Why We) (feat. Liam O'Donnell) [Dubdogz & SUBB Remix]	single
# 	Popular Monster (NGHTMRE & Galantis Remix)	single
# 	Don't Call Me (Galantis Remix)	single
# 	Tu Tu Tu (That's Why We)	single
# 	Only A Fool (with Pink Sweat$) [Remixes]	single
# 	Pretty Please	single
# 	The Rest of My Days (Galantis Remix)	single
# 	Only A Fool (with Pink Sweat$) [Marshall Jefferson Remix]	single
# 	Only A Fool (with Pink Sweat$) [DJ D-Sol Remix]	single
# 	Only A Fool (with Pink Sweat$)	single
# 	I Fly (feat. Faouzia)	single
# 	The Lake (with Wrabel)	single
# 	Holy Water (Steff da Campo Remix)	single
# 	Never Felt A Love Like This (feat. Dotan) [Remixes]	single
# 	Never Felt A Love Like This (with Hook N Sling) [feat. Dotan]	single
# 	Miracle (with Bali Bandits)	single
# 	Hurricane (with John Newman)	single
# 	Bonfire (with Steve James)	single
# 	Stella	single
# 	Unless It Hurts	single
# 	Steel	single
# 	Faith (with Dolly Parton) [feat. Mr. Probz] [Remixes]	single
# 	Faith (with Dolly Parton) [feat. Mr. Probz] [Acoustic]	single
# 	Faith (with Dolly Parton) [feat. Mr. Probz] [Galantis & Bali Bandits VIP Mix]	single
# 	Faith (with Dolly Parton) [feat. Mr. Probz] [JØRD Remix]	single
# 	Faith (with Dolly Parton) [feat. Mr. Probz] [Jewelz & Sparks Remix]	single
# 	Faith (with Dolly Parton) [feat. Mr. Probz]	single
# 	Holy Water	single
# 	We Can Get High (Remixes)	single
# 	We Can Get High (GATTÜSO Remix)	single
# 	We Can Get High (RetroVision Remix)	single
# 	We Can Get High	single
# 	I Found U	single
# 	Bones (feat. OneRepublic) [Remixes]	single
# 	Bones (feat. OneRepublic) [BotCash Remix]	single
# 	Think About You (Galantis Remix)	single
# 	Bones (feat. OneRepublic)	single
# 	Emoji (Remixes)	single
# 	San Francisco (with Sofia Carson)	single
# 	Emoji (Mark Villa Remix) & [BEAUZ Remix]	single
# 	Emoji	single
# 	Satisfied (feat. MAX) [Armand Van Helden x Cruise Control Remix]	single
# 	Satisfied (feat. MAX) / Mama Look at Me Now [Remixes, Pt. 2]	single
# 	Satisfied (feat. MAX) / Mama Look at Me Now [Remixes, Pt. 1]	single
# 	Summer Days (Galantis Remix)	single
# 	Satisfied (feat. MAX) / Mama Look at Me Now	single
# 	Spaceship (feat. Uffie) [Remixes]	single
# 	Spaceship (feat. Uffie) [Fourth Co. Remix]	single
# 	Spaceship (feat. Uffie)	single
# 	Tell Me You Love Me (Remixes Pt. 2)	single
# 	Tell Me You Love Me (Remixes)	single
# 	Tell Me You Love Me	single
# 	Too Good At Goodbyes (Galantis Remix)	single
# 	Fetish (feat. Gucci Mane) [Galantis Remix]	single
# 	True Feeling (Galantis & shndō VIP Mix)	single
# 	Hunter (Remixes)	single
# 	Rich Boy (Remixes)	single
# 	Bloodstain (Galantis Remix)	single
# 	Rich Boy	single
# 	Shape of You (Galantis Remix)	single
# 	Pillow Fight (Galantis & CID VIP Mix)	single
# 	Pillow Fight	single
# 	Love on Me Remixes	single
# 	Love on Me	single
# 	Make Me Feel [from XOXO the Netflix Original Film]	single
# 	Dominos (Galantis Remix)	single
# 	No Money Remixes, (Pt. 2)	single
# 	No Money (Remixes)	single
# 	No Money	single
# 	Louder, Harder, Better (Remixes)	single
# 	VIP Remixes	single
# 	In My Head (Remixes)	single
# 	Peanut Butter Jelly (Remixes)	single
# 	Runaway (U & I) [Svidden & Jarly Remix]	single
# 	Gold Dust (Remixes)	single
# 	Peanut Butter Jelly	single
# 	Runaway (U & I) [Remixes]	single
# 	Gold Dust	single
# 	Runaway (U & I) [Remixes]	single
# 	Runaway (U & I) [Dillon Francis Remix]	single
# 	Runaway (U & I) [Kaskade Remix]	single
# 	Runaway (U & I)	single
# 	Galantis Remixes EP	single
# 	You Remixes	single
# 	You (Brillz Remix)	single
# 	You (Tiësto vs. Twoloud Radio Edit)	single
# 	Galantis EP	single
# 	You	single
# 	Smile Remixes	single
# 	Smile	single
# 	Raveheart	single
# ///////////////////////////////////
# Eminem
# 	Tobey (feat. Big Sean and BabyTron)	single
# 	Houdini	single
# 	Lace It (with Eminem & benny blanco)	single
# 	Realest (with Eminem)	single
# 	From The D 2 The LBC (with Snoop Dogg)	single
# 	The King and I (feat. CeeLo Green) [From the Original Motion Picture Soundtrack ELVIS]	single
# 	Gospel (with Eminem)	single
# 	Last One Standing (feat. Polo G, Mozzy & Eminem) [From Venom: Let There Be Carnage]	single
# 	Killer (feat. Jack Harlow & Cordae) [Remix]	single
# 	The Adventures of Moon Man & Slim Shady (with Eminem)	single
# 	Remember The Name (feat. Eminem & 50 Cent)	single
# 	Homicide	single
# 	Venom (Music From The Motion Picture)	single
# 	Killshot	single
# 	Nowhere Fast (Extended Version)	single
# 	Chloraseptic (feat. 2 Chainz & Phresher) [Remix]	single
# 	Campaign Speech	single
# 	Rap God	single
# 	Beautiful (International Version)	single
# 	We Made You (International Version)	single
# 	Shake That (Radio Edit Version)	single
# 	When I'm Gone	single
# 	Ass Like That	single
# 	Mockingbird	single
# 	Just Lose It	single
# 	Infinite	single
# ///////////////////////////////////
# K/DA
# 	ALL OUT	single
# 	MORE	single
# 	THE BADDEST	single
# 	POP/STARS	single
# ///////////////////////////////////
# Die Antwoord
# 	Everything is Perfect	single
# 	REANIMATED	single
# 	BARUCH IN JOU OEG	single
# 	Age Of Illusion	single
# 	ZEF GOEMA MEGAMIX	single
# 	Baita Jou Sabela	single
# 	DntTakeMe4aPoes	single
# 	2•GOLDEN DAWN•7	single
# 	Love Drug	single
# 	Fat Faded Fuck Face	single
# 	We Have Candy	single
# 	Banana Brain	single
# 	Pitbull Terrier	single
# 	5 - EP	single
# ///////////////////////////////////
# Red Hot Chili Peppers
# 	The Shape I'm Takin'	single
# 	Eddie	single
# 	Tippa My Tongue	single
# 	Nerve Flip	single
# 	Not the One	single
# 	Poster Child	single
# 	Black Summer	single
# 	Goodbye Angels	single
# 	We Turn Red	single
# 	The Getaway	single
# 	Dark Necessities	single
# 	This Is the Kitt / Brave from Afar	single
# 	Hanalei / Open/Close	single
# 	Catch My Death / How It Ends	single
# 	In Love Dying	single
# 	Pink as Floyd / Your Eyes Girl	single
# 	The Sunset Sleeps / Hometown Gypsy	single
# 	Never Is a Long Time / Love of Your Life	single
# 	Magpies on Fire / Victorian Machinery	single
# 	Strange Man / Long Progression	single
# 	Rock & Roll Hall of Fame Covers - EP	single
# 	Snow (Hey Oh)	single
# 	Tell Me Baby	single
# 	Dani California	single
# 	Higher Ground / If You Want Me To Stay (Remixes)	single
# 	Higher Ground (Remixes)	single
# ///////////////////////////////////
# Jacob Tillberg
# 	Occupate My Mind	single
# 	Blinding Lights	single
# 	Still Lost	single
# 	Ghost Boy	single
# 	Flowers (Blackstripe Remix)	single
# 	Crossed the Line	single
# 	Flowers (RudeLies Remix)	single
# 	Memories	single
# 	Three Trees	single
# 	Flowers	single
# 	Talkin Bout Dancin	single
# 	Live Is Life	single
# 	Perfect (Jacob Tillberg Remix)	single
# 	Rhythm of the Night	single
# 	Mantra	single
# 	Broken	single
# 	How Deep	single
# 	Last Day	single
# 	Shape of You	single
# 	Damage	single
# 	Goes Back	single
# 	Burning On (Jacob Tillberg Remix)	single
# 	Apocalypse	single
# 	Kids Riot	single
# 	No Money	single
# 	Lsd, Not Even Once	single
# 	Last Kiss	single
# 	You	single
# 	Heartless	single
# 	Feel You	single
# 	Stay Young (feat. Brima)	single
# 	A Dream	single
# 	Counting Time	single
# 	Caffeine Rush	single
# 	The Rhythm	single
# 	Ghosts	single
# 	Sirens	single
# 	Soldier on Acid	single
# 	Funk & Drunk	single
# 	Very Very Way More Stronger	single
# 	Lost in Time	single
# 	Fade Away (Deaf Kev Remix)	single
# 	Rookie	single
# 	Fade Away	single
# 	Heaviness	single
# 	Yea Right EP	single
# ///////////////////////////////////
# Linkin Park
# 	QWERTY (Live in Tokyo, 2006)	single
# 	Friendly Fire: A Cappella + Instrumental	single
# 	Friendly Fire	single
# 	Evolution Of Mike Shinoda	single
# 	Lost (PLZ Tethered Version)	single
# 	Lost	single
# 	One Step Closer (100 gecs Reanimation)	single
# 	One More Light (Steve Aoki Chester Forever Remix)	single
# 	Darker Than The Light That Never Bleeds (Chester Forever Steve Aoki Remix)	single
# 	Heavy (feat. Kiiara)	single
# 	Final Masquerade	single
# 	Rebellion (feat. Daron Malakian)	single
# 	Interview: Mike Shinoda	single
# 	Wastelands	single
# 	Until It's Gone	single
# 	Guilty All the Same (feat. Rakim)	single
# 	A LIGHT THAT NEVER COMES REMIX	single
# 	A LIGHT THAT NEVER COMES	single
# 	Not Alone	single
# 	iTunes Festival - London, 2011	single
# 	Iridescent	single
# 	Waiting for the End	single
# 	The Catalyst	single
# 	New Divide	single
# 	Leave out All the Rest	single
# 	Given Up	single
# 	Shadow of the Day	single
# 	Shadow Of The Day	single
# 	Bleed It Out	single
# 	What I've Done (Int'l 2-Track)	single
# 	What I've Done	single
# 	Numb / Encore: MTV Ultimate Mash-Ups Presents Collision Course	single
# 	Dirt Off Your Shoulde r/ Lying From You: MTV Ultimate Mash-Ups Presents Collision Course	single
# 	Collision Course (Deluxe Version)	single
# ///////////////////////////////////
# VALORANT
# 	Villain (Take the Shot)	single
# 	UNDEFEATED	single
# 	2WORLDS	single
# 	Míranos	single
# 	MYTH.mix	single
# 	RE-IGNITION	single
# 	Savior	single
# 	Ticking Away	single
# 	REFLECTIONS	single
# 	>one (greater than one)	single
# 	LIMITLESS	single
# 	VISIONS	single
# 	All Eyes On Me	single
# 	RAJA	single
# 	Fire Again (Dabin Remix)	single
# 	Fire Again	single
# 	Die For You (Dabin Remix)	single
# 	Casa de Vidro (VALORANT Remix)	single
# 	Casa de Vidro	single
# 	Karanlığın	single
# 	Die For You (Zedd Remix)	single
# 	Die For You	single
# 	Ignition	single
# 	Watch	single
# ///////////////////////////////////
# Pendulum
# 	Anti-Hero (triple j Like A Version)	single
# 	Anima	single
# 	Mercy Killing	single
# 	Colourfast	single
# 	Halo (Urbandawn Remix)	single
# 	Halo (Matt Tuck Rework)	single
# 	Halo	single
# 	Elemental (The Remixes)	single
# 	Elemental	single
# 	The Island, Pt. 1 (Dawn) [Skrillex Remix]	single
# 	Tarantula (feat. DJ Fresh, $pyda, & Tenor Fly) [Icarus Remix]	single
# 	Blood Sugar (Knife Party Remix)	single
# 	Hold Your Colour (Noisia Remix)	single
# 	Crush (Radio Edit)	single
# 	The Island (Steve Angello, AN21 & Max Vangeli Remix)	single
# 	The Island	single
# 	Witchcraft	single
# 	Watercolour	single
# 	Showdown	single
# 	The Other Side	single
# 	Pendulum iTunes Live: London Festival '08 - EP	single
# 	In Silico Showcase	single
# 	Propane Nightmares	single
# 	Propane Nightmares	single
# 	Granite	single
# 	Granite	single
# 	Blood Sugar / Axel Grinder	single
# 	Hardware Limited, Vol. 3	single
# 	Hold Your Colour (Bi-Polar Remixes)	single
# 	Slam/Out Here	single
# 	Another Planet/Voyager	single
# 	Back 2 You	single
# 	Spiral / Ulterior Motive	single
# ///////////////////////////////////
# Knife Party
# 	Death & Desire (feat. Harrison) [Laidback Luke Remix]	single
# 	Ghost Train (Muzz Remix)	single
# 	Lost Souls (Annix Remix)	single
# 	Lost Souls EP	single
# 	Harpoon	single
# 	Battle Sirens (feat. Knife Party)	single
# 	Blood Sugar (Knife Party Remix)	single
# 	Battle Sirens (Ephwurd Remix)	single
# 	Battle Sirens (Brillz Remix)	single
# 	Battle Sirens (Live Version)	single
# 	Battle Sirens	single
# 	Trigger Warning	single
# 	Boss Mode	single
# 	Begin Again	single
# 	Resistance	single
# 	Haunted House	single
# 	100% No Modern Talking	single
# 	Rage Valley	single
# 	Antidote	single
# ///////////////////////////////////
# Bad Bunny
# 	ADIVINO	single
# 	UN PREVIEW	single
# 	K-POP	single
# 	WHERE SHE GOES	single
# 	un x100to	single
# 	Gato de Noche	single
# 	La Jumpa	single
# 	Lo Siento BB:/ (with Bad Bunny & Julieta Venegas)	single
# 	Volví	single
# 	Volando (Remix)	single
# 	De Museo	single
# 	AM Remix	single
# 	Yonaguni	single
# 	100 MILLONES	single
# 	DÁKITI	single
# 	Yo Perreo Sola (Remix)	single
# 	UN DIA (ONE DAY) (Feat. Tainy)	single
# 	CÓMO SE SIENTE (Remix)	single
# 	Ignorantes	single
# 	LOYAL (feat. Drake and Bad Bunny) [Remix]	single
# 	Vete	single
# 	Cántalo	single
# 	Soy El Diablo (Remix)	single
# 	Subimos de Rango	single
# 	Kemba Walker	single
# 	Bellacoso	single
# 	Estamos Arriba	single
# 	Callaita	single
# 	No Me Conoce (Remix)	single
# 	Soltera (Remix)	single
# 	Solo de Mi	single
# 	Te Guste	single
# 	MIA (feat. Drake)	single
# 	Está Rico	single
# 	Como Soy	single
# 	Vamos Pa' la Calle	single
# 	¿Cual Es Tu Plan?	single
# 	Satisfacción	single
# 	Original	single
# 	I Like It	single
# 	Te Descuidó	single
# 	Te Boté (Remix)	single
# 	Explícale (feat. Cosculluela & Brytiago) [Remix]	single
# 	Dime	single
# 	Loca Remix	single
# 	Dime Si Te Acuerdas	single
# 	Amorfoda	single
# 	Fantasía	single
# 	El Combo Me Llama 2	single
# 	Amantes de una Noche	single
# 	Krippy Kush (feat. Travis Scott & Rvssian) [Travis Scott Remix]	single
# 	Favorito De Los Capo (Remix)	single
# 	Chambea	single
# 	Krippy Kush (feat. 21 Savage & Rvssian) [Remix]	single
# 	Tu No Metes Cabra Remix	single
# 	Ahora Me Llama (Remix)	single
# 	Vuelve	single
# 	Mayores (Urban Tropical)	single
# 	Lean	single
# 	Báilame (Remix)	single
# 	Panamera (Remix)	single
# 	Me Llueven (Extenden Version)	single
# 	Mayores	single
# 	Tu No Metes Cabra	single
# 	Netflixxx	single
# 	Give It Up	single
# 	Demonia Baila	single
# 	Soy Peor Remix	single
# 	Un Ratito Mas	single
# 	Ahora Me Llama	single
# 	Blockia	single
# 	Me Mata	single
# 	Trepate	single
# 	Tranquilo	single
# 	No Te Hagas	single
# 	Me Llueven 3.0	single
# 	Me Llueven 2	single
# 	Amigos y Enemigos (Remix)	single
# 	Crecia	single
# 	Pa Ti	single
# 	Caile	single
# 	Otra Vez (Remake)	single
# 	Soy Peor	single
# 	Tu No Vive Asi (feat. Mambo Kingz & DJ Luian)	single
# 	Diles	single
# 	Otra Vez	single
# ///////////////////////////////////
# Anuel AA
# 	Baby Demon	single
# 	Razones	single
# 	WYA REMIX BLACK AND YELLOW (feat. iZaak & Pirlo)	single
# 	Hasta la Muerte	single
# 	XQCP	single
# 	Bellakita	single
# 	Toki	single
# 	Kilerito	single
# 	No Te Quieren Conmigo (Remix) (Gaby Music, Anuel AA, Luar LA L)	single
# 	BBY BOO (REMIX)	single
# 	VVS Switch (feat. Hades66, Luar La L & CDobleta) [Remix]	single
# 	Tacos Gucci	single
# 	Rebound (feat. Anuel AA)	single
# 	Luces Tenues	single
# 	Arcangel Es Chota	single
# 	Glock, Glock, Glock	single
# 	Alcohol	single
# 	OA	single
# 	Oh Na Na	single
# 	Corazón Roto pt. 3	single
# 	PARA SIEMPRE	single
# 	Podemos Repetirlo (Remix)	single
# 	PACTO (Remix) [feat. Bryant Myers & Dei V]	single
# 	Baby	single
# 	Milloneta	single
# 	Mejor Que Yo	single
# 	MI EXXX	single
# 	Triste Verano	single
# 	Diablo, Qué Chimba	single
# 	Mas Rica Que Ayer	single
# 	Drippin	single
# 	Wakanda	single
# 	Vibra	single
# 	Sufro	single
# 	Mientes	single
# 	Del Kilo	single
# 	Airbnb	single
# 	1ro	single
# 	La Máquina	single
# 	Hoodie	single
# 	Si Yo Me Muero	single
# 	Presidentes Muertos	single
# 	MUEVELO	single
# 	DURO	single
# 	Diamantes En Mis Dientes	single
# 	EL NENE	single
# 	La 2blea	single
# 	Brother	single
# 	Nosotros	single
# 	Mercedes Tintia	single
# 	Delincuente	single
# 	Malo	single
# 	¿Qué Nos Pasó?	single
# 	La Llevo Al Cielo (Ft. Ñengo Flow)	single
# 	Si Tu Me Busca	single
# 	Súbelo	single
# 	Leyenda	single
# 	Anuel AA: Bzrp Music Sessions, Vol. 46	single
# 	Dictadura	single
# 	Ley Seca	single
# 	23 Preguntas	single
# 	Los De Siempre	single
# 	Fiel (Remix)	single
# 	Whoopty (Latin Mix) [feat. Anuel AA and Ozuna]	single
# 	LOCATION	single
# 	Lemonade (feat. Don Toliver & NAV) [Latin Remix]	single
# 	Diosa (Remix)	single
# 	Reloj	single
# 	Don Don (Remix)	single
# 	Don Don	single
# 	Reggaetonera (Clean Version)	single
# 	Fútbol & Rumba (feat. Enrique Iglesias)	single
# 	Sur y Norte	single
# 	La Bebe (Remix)	single
# 	Conversacion Con Dios	single
# 	La Jeepeta (Remix)	single
# 	Illuminati	single
# 	No Me Ame	single
# 	Sola & Vacía	single
# 	3 de Abril	single
# 	Follow	single
# 	Fantasias (Remix) [feat. Farruko & Lunay]	single
# 	Keii	single
# 	Medusa	single
# 	Me Gusta	single
# 	Gan-Ga (Remix)	single
# 	Gan-Ga (Remix)	single
# 	YES	single
# 	Adicto (with Anuel AA & Ozuna)	single
# 	Otro Trago (Remix)	single
# 	China	single
# 	Cambio	single
# 	LHNA (with Anuel AA)	single
# 	GET MONEY	single
# 	Por Ley	single
# 	Guayo	single
# 	Ven y Hazlo Tú (feat. Arcángel)	single
# 	No Te Veo	single
# 	Verte Ir	single
# 	Fulete	single
# 	Controla	single
# 	Como Soy II	single
# 	Secreto	single
# 	Te Boté (RHLM)	single
# 	Nanana	single
# 	Amanece	single
# 	A Solas (Remix)	single
# 	Adictiva	single
# 	Ella Quiere Beber (Remix)	single
# 	Que Sería	single
# 	Con Silenciador	single
# 	Culpables	single
# 	Armao 100pre Andamos	single
# 	Las Babys Me Llaman	single
# 	Rojo	single
# 	Armao 100pre Andamos (Remix)	single
# 	23	single
# 	Si Tu Quiere (feat. Pusho)	single
# 	Ayer 2 (feat. Dj Nelson, J Balvin, Nicky Jam, Cosculluela)	single
# 	Seduceme	single
# 	Maliante Hp	single
# 	47 (Remix)	single
# 	Ceniza En Cenicero	single
# 	Cristiniando	single
# 	No Forcen	single
# 	No Soy Romantico	single
# 	Sola (Remix)	single
# 	47	single
# 	Nacimos Pa Morir (feat. Jory Boy)	single
# 	Ayer	single
# 	Ayer	single
# 	Amigos	single
# 	Voltea	single
# 	Work	single
# 	No Love	single
# 	La Bella y La Bestia	single
# 	Check	single
# 	Liberace	single
# 	Coronamos	single
# 	Death Before Dishonor	single
# 	Nunca Sapo	single
# 	Las Cosas No Están Como Antes	single
# 	Lesbihonest (feat. Jae Coop)	single
# 	Death Before Dishonor (Remix) [feat. Magazeen, Angel Doze & Alexis]	single
# 	Pronto Volveré	single
# 	En El Castillo	single
# 	Sola	single
# 	Jersey (feat. Darell)	single
# 	Me Quieren Matar	single
# 	Flores Violetas	single
# 	Maliante Hp	single
# 	Soldado Y Profeta (Remix) [feat. Ozuna, Almighty, Kendo & Ñengo Flow]	single
# 	69 (Remix) [feat. Ozuna]	single
# ///////////////////////////////////
# M|O|O|N
# 	Waste Away	single
# 	Dance Music For DJs	single
# 	Trackmania NEO-CUPRA: District 1 // Velocity (Original Game Soundtrack)	single
# 	Come Alone	single
# 	Grift	single
# 	Alicia	single
# 	Timestamp	single
# 	Chlorophyll	single
# 	Rubber	single
# 	Quixotic	single
# 	DAY/NIGHT	single
# 	Particles E.P.	single
# 	MOON E.P.	single
# ///////////////////////////////////
# La Mente
# 	Patrimonio	single
# 	Falta la Mitad	single
# 	Los Enfermos Remix Level Up	single
# 	Este Amor No Es para Cobardes Remix Level Up	single
# 	La Palabra del Ciego	single
# ///////////////////////////////////
# Three Days Grace
# 	Somebody That I Used to Know	single
# 	You Don't Get Me High Anymore	single
# 	Break	single
# 	Animal I Have Become	single
# 	Never Too Late	single
# 	Pain (+ Acoustic) - Single	single
# 	Pain (Acoustic Version)	single
# 	Pain	single
# 	I Hate Everything About You	single
# 	I Hate Everything About You (Acoustic Version)	single
# 	Rolling Stone Original (EP)	single
# ///////////////////////////////////
# Fadex
# 	La méchanceté de l'homme	single
# 	Glasshouse (Fadex Flip)	single
# 	You Didn't Do Nothing Bad	single
# 	Igloo	single
# 	Time Stops	single
# 	Mindfuck	single
# 	Mhm	single
# 	Starfall	single
# 	I.L.Y.	single
# 	Garia	single
# 	Fearless	single
# 	Pokemon Riot	single
# 	Nice Shot!	single
# 	Dance Machine	single
# 	Vivant	single
# 	Sonder	single
# 	Wubbles	single
# 	Truecolor Alchemist	single
# 	Our Way	single
# ///////////////////////////////////
# La Nueva Invasión
# 	Haciéndolo Mejor	single
# 	Cuatro Paredes	single
# 	Yo Te Quiero Asi	single
# 	La Nueva Ya Llego	single
# ///////////////////////////////////
# Avicii
# 	Malo (The Cube Guys Remix)	single
# 	Street Dancer (Sgt Slick's Discotizer 2022 Remix)	single
# 	My Feelings For You (Mark Knight Remix)	single
# 	My Feelings For You (Don Diablo Remix)	single
# 	Forever Yours (Avicii Tribute)	single
# 	Fades Away (feat. MishCatt) [Tribute Concert Version]	single
# 	Heaven (David Guetta & MORTEN Remix)	single
# 	Tough Love (Tiësto Remix)	single
# 	SOS (Laidback Luke Tribute Remix)	single
# 	Tough Love (feat. Vargas & Lagola)	single
# 	SOS (feat. Aloe Blacc)	single
# 	Lonely Together (Remixes)	single
# 	Lonely Together (Acoustic)	single
# 	Without You (Remixes)	single
# 	AVĪCI (01)	single
# 	Taste The Feeling (Avicii Vs. Conrad Sewell)	single
# 	Pure Grinding (iSHi Remix)	single
# 	Broken Arrows (Remixes)	single
# 	For A Better Day (Remixes)	single
# 	For A Better Day (KSHMR Remix)	single
# 	Waiting For Love (Remixes Pt. II)	single
# 	Waiting For Love (Remixes)	single
# 	Feeling Good	single
# 	The Days / Nights	single
# 	The Nights (Avicii By Avicii)	single
# 	You Make Me (Diplo Remix)	single
# 	Lay Me Down (Black Coffee Remix)	single
# 	Addicted To You (Remixes)	single
# 	Speed (Burn & Lotus Team F1 Mix)	single
# 	I Could Be The One [Avicii vs Nicky Romero] (Noonie Bao Acoustic Mix)	single
# 	I Could Be The One [Avicii vs Nicky Romero] (Remixes)	single
# 	You Make Me (Remixes)	single
# 	X You	single
# 	Wake Me Up (Remixes)	single
# 	Wake Me Up (Remixes II)	single
# 	True (Preview Mix)	single
# 	Hey Brother (Remixes)	single
# 	I Could Be The One [Avicii vs Nicky Romero]	single
# 	Last Dance (Remixes)	single
# 	Silhouettes (Remixes)	single
# 	Superlove	single
# 	Silhouettes	single
# 	Levels (Remixes)	single
# 	Levels	single
# 	Fade Into Darkness (Remixes)	single
# 	Collide	single
# 	Collide (Radio Edit)	single
# 	Sweet Dreams (Remixes)	single
# 	Fade Into Darkness	single
# 	Street Dancer	single
# 	Street Dancer	single
# 	Sweet Dreams	single
# 	Snus	single
# 	Malo	single
# 	Jailbait	single
# 	Malo [Radio Edit]	single
# 	I Feel Love (Avicii's Forgotten Edit)	single
# 	Don't Hold Back (John Dahlbäck & Avicii Extended Remix)	single
# 	Bromance (Avicii's Arena Mix)	single
# 	BOM	single
# 	My Feelings For You	single
# 	Ryu / Strutnut	single
# 	So Excited	single
# 	Muja	single
# 	Set Me Free (Avicii Radio Edit)	single
# 	Even	single
# 	Sound Of Now	single
# ///////////////////////////////////
# Pitbull
# 	2 The Moon	single
# 	Tequila	single
# 	Powerful Women	single
# 	Good Life	single
# 	Get Get Get Down	single
# 	Pasame La Botella	single
# 	Triple M	single
# 	Suave	single
# 	Lit In The City	single
# 	It Takes 3	single
# 	Let's Take A Shot	single
# 	Freak 54 (Freak Out)	single
# 	Freak 54 (Freak Out) [Sped Up Version]	single
# 	JUMPIN (Timmy Trumpet Remix)	single
# 	JUMPIN	single
# 	Me Pone Mal	single
# 	Mami	single
# 	RIGHT OR WRONG (HYPNOSIS)	single
# 	Bandida	single
# 	Mamasota	single
# 	QUE SE JODA	single
# 	Party of a Lifetime (Birthday Edit)	single
# 	Discoteca (Deorro Remix)	single
# 	Café Con Leche	single
# 	Discoteca (The Remixes)	single
# 	Can't Stop Us Now (Nitti Gritti Remix)	single
# 	Discoteca (Benny Benassi Remix)	single
# 	Can't Stop Us Now	single
# 	I Feel Good (71 Digits Remix)	single
# 	Discoteca	single
# 	I Feel Good (Sak Noel X Salvi X Franklin Dam Remix)	single
# 	I Feel Good (R3HAB Remix)	single
# 	I Know You Want Me (Calle Ocho) [Helion Remix]	single
# 	I Feel Good	single
# 	Where the Country Girls At	single
# 	Ten Cuidado	single
# 	Cosita Linda	single
# 	Give It To Me	single
# 	Que Rica (Tocame)	single
# 	Voodoo	single
# 	Moviéndolo (Remix)	single
# 	Borracha (Pero Buena Muchacha)	single
# 	Backpack	single
# 	Te Quiero Baby (I Love You Baby)	single
# 	Mala (feat. Becky G & De La Ghetto)	single
# 	I Believe That We Will Win (World Anthem) [Thombs Remixes]	single
# 	I Believe That We Will Win (World Anthem)	single
# 	Suda (Remixes)	single
# 	Suda (Deluxe)	single
# 	Get Ready	single
# 	Suda	single
# 	Me Quedaré Contigo (Shndō Remix)	single
# 	Further Up (Na, Na, Na, Na, Na)	single
# 	Imagínate	single
# 	3 to Tango	single
# 	No Lo Trates	single
# 	YAYO	single
# 	La Reina De Blanco	single
# 	Body On My	single
# 	Dame Tu Cosita (feat. Cutty Ranks) [Remixes]	single
# 	Quiero Saber	single
# 	Dame Tu Cosita (feat. Cutty Ranks) [Radio Version]	single
# 	Echa Pa Aca	single
# 	Free Free Free	single
# 	So Sorry	single
# 	MOVE TO MIAMI (Darell Version)	single
# 	Amore	single
# 	MOVE TO MIAMI	single
# 	Scooby Doo Pa Pa (Remix) - Single	single
# 	Muévelo Loca Boom Boom	single
# 	Mucho Booty	single
# 	Better On Me (The Remixes) (feat. Ty Dolla $ign)	single
# 	Jungle (feat. E-40 & Abraham Mateo)	single
# 	Por Favor	single
# 	Options (The Remixes 2) (feat. Stephen Marley)	single
# 	Hey Ma (with J Balvin & Pitbull feat. Camila Cabello)	single
# 	Hey Ma (with Pitbull & J Balvin feat. Camila Cabello)	single
# 	Options (feat. Stephen Marley)	single
# 	Options (The Remixes) (feat. Stephen Marley)	single
# 	Can't Have (feat. Steven A. Clark & Ape Drums)	single
# 	Greenlight (The Remixes) (feat. Flo Rida & LunchMoney Lewis)	single
# 	Greenlight (feat. Flo Rida & LunchMoney Lewis)	single
# 	Messin' Around (w/ Enrique Iglesias) (with Enrique Iglesias)	single
# 	Superstar	single
# 	Soulmate (feat. Pitbull)	single
# 	El Taxi (Remixes)	single
# 	Bad Man	single
# 	Freedom	single
# 	FREE.K Remixes	single
# 	El Taxi (Spanglish Remix)	single
# 	U Know It Ain't Love (feat. Pitbull)	single
# 	FREE.K	single
# 	Piensas (Dile La Verdad) [Remix]	single
# 	Baddest Girl in Town (International Remix)	single
# 	Fun (Remixes) (feat. Chris Brown)	single
# 	Time of Our Lives	single
# 	Celebrate (From the Original Motion Picture "Penguins of Madagascar")	single
# 	Yo Quiero	single
# 	Fireball (feat. John Ryan)	single
# 	We Are One (Ole Ola) [The Official 2014 FIFA World Cup Song] (Opening Ceremony Version) (feat. Jennifer Lopez & Claudia Leitte)	single
# 	We Are One (Ole Ola) [The Official 2014 FIFA World Cup Song] (feat. Jennifer Lopez & Claudia Leitte) [Olodum Mix]	single
# 	We Are One (Ole Ola) [The Official 2014 FIFA World Cup Song] (feat. Jennifer Lopez & Claudia Leitte)	single
# 	Wild Wild Love (feat. G.R.L.)	single
# 	Noche No Termina	single
# 	Echa Pa'lla (Manos Pa'rriba) (feat. Papayo)	single
# 	Timber	single
# 	Feel This Moment Remixes (feat. Christina Aguilera)	single
# 	Don't Stop the Party (feat. TJR)	single
# 	Beat On My Drum	single
# 	Get It Started (feat. Shakira)	single
# 	Back in Time (featured in "Men In Black 3")	single
# 	I Like - The Remix (feat. Enrique Iglesias & Afrojack)	single
# 	Crazy People (DJ Buddha Clean Version)	single
# 	Crazy People	single
# 	Pause (Zumba Mix)	single
# 	Give Me Everything: The Remixes	single
# 	Turn Around (Pt. 2)	single
# 	Hey Baby (Drop It To The Floor) - The Remixes EP	single
# 	Bon Bon	single
# 	Ridin' It Raw	single
# 	Dem Miami Boyz	single
# 	Hey Baby (Drop It To The Floor)	single
# 	Hey Baby (Drop It to the Floor) (feat. T-Pain)	single
# 	Game On	single
# 	Shut It Down	single
# 	Pearly Gates (feat. Nayer)	single
# 	Pearly Gates (feat. Nayer)	single
# 	Armada Latina (feat. Pitbull and Marc Anthony)	single
# 	Shut It Down (feat. Akon)	single
# 	Hotel Room Service (feat. Nicole Scherzinger) [Remix]	single
# 	Hotel Room Service	single
# 	Krazy (feat. Lil Jon)	single
# 	Krazy (feat. Lil Jon) [Spanish Version]	single
# 	Blanco	single
# 	I Know You Want Me (Calle Ocho)	single
# 	Krazy featuring Lil Jon (Spanish Version)	single
# 	Krazy - Feat. Lil Jon (Clean Version)	single
# 	Go Girl (Sped Up)	single
# 	Unreleased	single
# 	Sticky Icky - Single	single
# 	Tell Me - Single	single
# 	Bojangles - Single	single
# 	Shake Feat. Pitbull	single
# Consulta exitosa

# %%
list_tracks_album = []
list_total_compilations_albums = []
#Iteración de artistas
for index, row in df_user_top_artists_extract.iterrows():
    print("///////////////////////////////////")
    print(row['name_artist'])
    id_artist = row['id_artist']
    limit = 50
    offset = 0
    country = 'US'
    include_groups= 'compilation'
    #Iteración de paginación de albumes del artista
    while True:
        results = sp.artist_albums(id_artist, country=country, include_groups=include_groups, limit=limit, offset=offset)
        #Iteración de los albumnes del artista
        for item in enumerate(results['items']):
            # Pausa para manejar límites de tasa
            time.sleep(1)
            item = item[1]
            type_album = item['album_type']
            total_tracks_album = item['total_tracks']
            id_album = item['id']
            name_album = item['name']
            release_date_album = item['release_date']
            print("\t" + name_album + "\t" + type_album)
            #Más informacion del album
            dict_album = sp.album(id_album, 'US')
            popularity_album = dict_album['popularity']
            duration_ms_total_album = 0            
            list_tracks_album = dict_album['tracks']['items']
            for track in list_tracks_album:
                duration_ms_total_album = duration_ms_total_album + int(track['duration_ms'])       
            list_total_compilations_albums.append(
                [
                    id_album
                    , id_artist
                    , name_album
                    , type_album
                    , popularity_album
                    , total_tracks_album
                    , release_date_album
                    , duration_ms_total_album
                ]
            )
        if len(results['items']) < limit:
            break
        offset = offset + limit
        
        # Pausa para manejar límites de tasa
        time.sleep(1)
        
print("Consulta exitosa")
# Out:
# ///////////////////////////////////
# Gorillaz
# 	Gorillaz Are Ten - Spotify Radio Show 3	compilation
# 	Gorillaz Are Ten - Spotify Radio Show 2	compilation
# 	The Singles Collection 2001-2011	compilation
# 	Gorillaz Are Ten - Spotify Radio Show 1	compilation
# 	G-Sides	compilation
# ///////////////////////////////////
# Proleter
# ///////////////////////////////////
# The Weeknd
# 	The Highlights (Deluxe)	compilation
# 	The Highlights	compilation
# ///////////////////////////////////
# League of Legends
# ///////////////////////////////////
# Skrillex
# ///////////////////////////////////
# Daft Punk
# 	Musique, Vol. 1	compilation
# ///////////////////////////////////
# Nirvana
# 	Sliver - The Best Of The Box	compilation
# 	With The Lights Out - Box Set	compilation
# 	Nirvana	compilation
# ///////////////////////////////////
# De Hofnar
# 	Armada Invites (In The Mix): De Hofnar	compilation
# ///////////////////////////////////
# Florence + The Machine
# 	Under Heaven Over Hell	compilation
# 	Harder Than Hell	compilation
# 	My Favorite Ghosts	compilation
# 	Water To Drink Not Write About	compilation
# ///////////////////////////////////
# Metro Boomin
# ///////////////////////////////////
# El Cuarteto De Nos
# 	Grandes Exitos / Greatest Hits	compilation
# ///////////////////////////////////
# Galantis
# ///////////////////////////////////
# Eminem
# 	Eminem Presents The Re-Up	compilation
# 	Curtain Call: The Hits (Deluxe Edition)	compilation
# 	Curtain Call: The Hits	compilation
# ///////////////////////////////////
# K/DA
# ///////////////////////////////////
# Die Antwoord
# ///////////////////////////////////
# Red Hot Chili Peppers
# 	The Studio Album Collection 1991 - 2011	compilation
# 	Greatest Hits	compilation
# 	What Hits!?	compilation
# ///////////////////////////////////
# Jacob Tillberg
# ///////////////////////////////////
# Linkin Park
# 	LOST DEMOS	compilation
# ///////////////////////////////////
# VALORANT
# ///////////////////////////////////
# Pendulum
# ///////////////////////////////////
# Knife Party
# ///////////////////////////////////
# Bad Bunny
# ///////////////////////////////////
# Anuel AA
# ///////////////////////////////////
# M|O|O|N
# ///////////////////////////////////
# La Mente
# ///////////////////////////////////
# Three Days Grace
# ///////////////////////////////////
# Fadex
# 	Compilation	compilation
# ///////////////////////////////////
# La Nueva Invasión
# ///////////////////////////////////
# Avicii
# 	True Reveal	compilation
# ///////////////////////////////////
# Pitbull
# 	Greatest Hits	compilation
# 	Original Hits	compilation
# Consulta exitosa

# %%
list_tracks_album = []
list_total_appears_on_albums = []
#Iteración de artistas
for index, row in df_user_top_artists_extract.iterrows():
    print("///////////////////////////////////")
    print(row['name_artist'])
    id_artist = row['id_artist']
    limit = 50
    offset = 0
    country = 'US'
    include_groups= 'appears_on'
    #Iteración de paginación de albumes del artista
    while True:
        results = sp.artist_albums(id_artist, country=country, include_groups=include_groups, limit=limit, offset=offset)
        #Iteración de los albumnes del artista
        for item in enumerate(results['items']):
            # Pausa para manejar límites de tasa
            time.sleep(1)
            item = item[1]
            type_album = item['album_type']
            total_tracks_album = item['total_tracks']
            id_album = item['id']
            name_album = item['name']
            release_date_album = item['release_date']
            print("\t" + name_album + "\t" + type_album)
            #Más informacion del album
            dict_album = sp.album(id_album, 'US')
            popularity_album = dict_album['popularity']
            duration_ms_total_album = 0            
            list_tracks_album = dict_album['tracks']['items']
            for track in list_tracks_album:
                duration_ms_total_album = duration_ms_total_album + int(track['duration_ms'])       
            list_total_appears_on_albums.append(
                [
                    id_album
                    , id_artist
                    , name_album
                    , type_album
                    , popularity_album
                    , total_tracks_album
                    , release_date_album
                    , duration_ms_total_album
                ]
            )
        if len(results['items']) < limit:
            break
        offset = offset + limit
        
        # Pausa para manejar límites de tasa
        time.sleep(1)
        
print("Consulta exitosa")

# %%
list_total_albums = list_total_albums_albums + list_total_singles_albums + list_total_compilations_albums ##+ list_total_appears_on_albums

# %%
df_albums_fav_artists_extract = pd.DataFrame(list_total_albums, columns = [
    'id_album'
    , 'id_artist'
    , 'name_album'
    , 'type_album'
    , 'popularity_album'
    , 'total_tracks_album'
    , 'release_date_album'
    , 'duration_ms_total_album'
    ])

# %%
df_albums_fav_artists_extract['extract_datetime'] = datetime.now()

# %%
df_albums_fav_artists_extract.to_csv('fuente/extraccion/albums_fav_artists.csv', sep='|', index=False)

# %%
df_albums_fav_artists_extract.to_excel('fuente/extraccion/albums_fav_artists.xlsx', index=False)

# %% [markdown]
# ### Extraer: Las canciones más populares de mis artistas favoritos
# Obtener un dataframe de las canciones más populares de mis artistas favoritos

# %%
list_dict_top_tracks_fav_artists_extract = []
for index, row in df_user_top_artists_extract.iterrows():
    index_artist = index
    name_artist = row['name_artist']
    id_artist = row['id_artist']
    list_dict_top_tracks_fav_artists_extract.append(
        dict(name_artist = name_artist, id_artist = id_artist, index_artist = index, top_tracks = sp.artist_top_tracks(id_artist, country='US'))
    )

# %%
list_top_tracks_fav_artists_extract = []
for row in list_dict_top_tracks_fav_artists_extract:
    index_track = 0
    for track in row['top_tracks']['tracks']:
        position_track = index_track
        user_rank_artist = row['index_artist']
        id_artist = row['id_artist']
        id_track = track['id']
        id_album = track['album']['id']
        name_track = track['name']
        duration_track_ms = track['duration_ms']
        popularity_track = track['popularity']
        number_track = track['track_number']
        list_top_tracks_fav_artists_extract.append(
            [
            id_track
            , id_artist
            , id_album
            , name_track
            , duration_track_ms
            , popularity_track
            , number_track
            , position_track
            ]
        )
        index_track = index_track + 1

# %%
df_top_tracks_fav_artists_extract = pd.DataFrame(list_top_tracks_fav_artists_extract, columns = [
            'id_track'
            , 'id_artist'
            , 'id_album'
            , 'name_track'
            , 'duration_track_ms'
            , 'popularity_track'
            , 'number_track'
            , 'position_track'])

# %%
df_top_tracks_fav_artists_extract['extract_datetime'] = datetime.now()

# %%
df_top_tracks_fav_artists_extract.to_csv('fuente/extraccion/top_tracks_fav_artists.csv', sep='|', index=False)

# %%
df_top_tracks_fav_artists_extract.to_excel('fuente/extraccion/top_tracks_fav_artists.xlsx', index=False)

# %% [markdown]
# ## Transformacion

# %% [markdown]
# ### Transformacion: Crear columna duration_track_ms en segundos y en minutos del df_top_tracks_fav_artists

# %%
df_top_tracks_fav_artists_transform = df_top_tracks_fav_artists_extract.copy()

# %%
df_top_tracks_fav_artists_transform = df_top_tracks_fav_artists_transform[
    ['id_track'
    , 'id_artist'
     , 'id_album'
     , 'name_track'
     , 'duration_track_ms'
     , 'popularity_track'
     , 'number_track'
     , 'position_track']
]

# %%
df_top_tracks_fav_artists_transform['duration_track_seconds'] = df_top_tracks_fav_artists_transform['duration_track_ms'] / 1000.0

# %%
df_top_tracks_fav_artists_transform['duration_track_minutes'] = df_top_tracks_fav_artists_transform['duration_track_ms'] / (1000.0 * 60.0)

# %%
df_top_tracks_fav_artists_transform['transform_datetime'] = datetime.now()

# %%
df_top_tracks_fav_artists_transform.head(5)
# Out:
#                  id_track               id_artist                id_album  \
# 0  0d28khcov6AiegSCpG5TuT  3AA28KZvwAUcZuOKwyblJQ  0bUTHlWbkSQysoM3VsWldT
# 1  0q6LuUqGLUiCPP1cbdwFs3  3AA28KZvwAUcZuOKwyblJQ  2dIGnmEIy1WZIcZCFSj6i8
# 2  1RKUoGiLEbcXN4GY4spQDx  3AA28KZvwAUcZuOKwyblJQ  4tUxQkrduOE8sfgwJ5BI2F
# 3  4Hff1IjRbLGeLgFgxvHflk  3AA28KZvwAUcZuOKwyblJQ  0bUTHlWbkSQysoM3VsWldT
# 4  1foMv2HQwfQ2vntFf9HFeG  3AA28KZvwAUcZuOKwyblJQ  2dIGnmEIy1WZIcZCFSj6i8
#
#            name_track  duration_track_ms  popularity_track  number_track  \
# 0      Feel Good Inc.             222640                84             6
# 1  On Melancholy Hill             233866                78            10
# 2      Clint Eastwood             340920                75             5
# 3                DARE             244999                76            12
# 4     Rhinestone Eyes             200173                75             4
#
#    position_track  duration_track_seconds  duration_track_minutes  \
# 0               0                 222.640                3.710667
# 1               1                 233.866                3.897767
# 2               2                 340.920                5.682000
# 3               3                 244.999                4.083317
# 4               4                 200.173                3.336217
#
#           transform_datetime
# 0 2024-07-16 08:36:45.339420
# 1 2024-07-16 08:36:45.339420
# 2 2024-07-16 08:36:45.339420
# 3 2024-07-16 08:36:45.339420
# 4 2024-07-16 08:36:45.339420

# %% [markdown]
# ### Transformacion: Crear columna duration_ms_total_album en segundos y en minutos del df_top_albums_fav_artists

# %%
df_top_albums_fav_artists_transform = df_top_albums_fav_artists_extract.copy()

# %%
df_top_albums_fav_artists_transform = df_top_albums_fav_artists_transform[
    ['id_album'
     , 'id_artist'
     , 'name_album'
     , 'type_album'
     , 'total_tracks_album'
     , 'release_date_album'
     , 'duration_ms_total_album'
    ,  'populariy_album']
]

# %%
df_top_albums_fav_artists_transform['duration_total_seconds_album'] = df_top_albums_fav_artists_transform['duration_ms_total_album'] / 1000.0

# %%
df_top_albums_fav_artists_transform['duration_total_minutes_album'] = df_top_albums_fav_artists_transform['duration_ms_total_album'] / (1000.0 * 60.0)

# %%
df_top_albums_fav_artists_transform['transform_datetime'] = datetime.now()

# %%
df_top_albums_fav_artists_transform.head(5)
# Out:
#                  id_album               id_artist       name_album type_album  \
# 0  0bUTHlWbkSQysoM3VsWldT  3AA28KZvwAUcZuOKwyblJQ       Demon Days      album
# 1  2dIGnmEIy1WZIcZCFSj6i8  3AA28KZvwAUcZuOKwyblJQ    Plastic Beach      album
# 2  4tUxQkrduOE8sfgwJ5BI2F  3AA28KZvwAUcZuOKwyblJQ         Gorillaz      album
# 3  0NvirtaDCaZU5PAW1O5FDE  3AA28KZvwAUcZuOKwyblJQ  Humanz (Deluxe)      album
# 4  4wtZQMNTC1O79kDxMBsEan  3AA28KZvwAUcZuOKwyblJQ   Cracker Island      album
#
#    total_tracks_album release_date_album  duration_ms_total_album  \
# 0                  15         2005-05-23                  3102755
# 1                  16         2010-03-03                  3413486
# 2                  17         2001-03-26                  3880901
# 3                  26         2017-04-28                  4151469
# 4                  10         2023-02-24                  2249194
#
#    populariy_album  duration_total_seconds_album  \
# 0               80                      3102.755
# 1               76                      3413.486
# 2               70                      3880.901
# 3               70                      4151.469
# 4               67                      2249.194
#
#    duration_total_minutes_album         transform_datetime
# 0                     51.712583 2024-07-16 08:36:48.648229
# 1                     56.891433 2024-07-16 08:36:48.648229
# 2                     64.681683 2024-07-16 08:36:48.648229
# 3                     69.191150 2024-07-16 08:36:48.648229
# 4                     37.486567 2024-07-16 08:36:48.648229

# %% [markdown]
# ### Transformacion: Crear columna duration_ms_total_album en segundos y en minutos del df_albums_fav_artists_extract

# %%
df_albums_fav_artists_transform = df_albums_fav_artists_extract.copy()

# %%
df_albums_fav_artists_transform = df_albums_fav_artists_transform[
    ['id_album'
     , 'id_artist'
     , 'name_album'
     , 'type_album'
     , 'popularity_album'
     , 'total_tracks_album'
     , 'release_date_album'
     , 'duration_ms_total_album']
]

# %%
df_albums_fav_artists_transform['duration_seconds_total_album'] = df_albums_fav_artists_transform['duration_ms_total_album'] / 1000.0

# %%
df_albums_fav_artists_transform['duration_minutes_total_album'] = df_albums_fav_artists_transform['duration_ms_total_album'] / (1000.0 * 60.0)

# %% [markdown]
# ### Transformacion: Formatear campo release_date_album df_albums_fav_artists_extract

# %%
df_albums_fav_artists_transform['release_date_album'] = df_albums_fav_artists_transform['release_date_album'].apply(
    lambda x: x + '-01-01' if pd.Series(x).str.match(r'^\d{4}$')[0] else x
)

# %%
df_albums_fav_artists_transform['transform_datetime'] = datetime.now()

# %% [markdown]
# ### Transformacion: user_top_artists

# %%
df_user_top_artists_transform = df_user_top_artists_extract.copy()

# %%
df_user_top_artists_transform = df_user_top_artists_transform[
    ['id_artist'
     , 'name_artist'
     , 'q_followers'
     , 'popularity']
]

# %%
current_datetime = datetime.now()

# %%
df_user_top_artists_transform['transform_datetime'] = current_datetime

# %%
df_user_top_artists_transform.head(5)
# Out:
#                 id_artist        name_artist  q_followers  popularity  \
# 0  3AA28KZvwAUcZuOKwyblJQ           Gorillaz     11827037          79
# 1  5dCpFeKxLbycrnsjWZjha8           Proleter       119145          44
# 2  1Xyo4u8uXC1ZmMpatF05PJ         The Weeknd     86127221          93
# 3  47mIJdHORyRerp4os813jD  League of Legends      1863031          75
# 4  5he5w2lnU9x7JFhnwcekXX           Skrillex      7604981          75
#
#           transform_datetime
# 0 2024-07-16 08:36:55.531502
# 1 2024-07-16 08:36:55.531502
# 2 2024-07-16 08:36:55.531502
# 3 2024-07-16 08:36:55.531502
# 4 2024-07-16 08:36:55.531502

# %% [markdown]
# ### Exportación final

# %%
df_albums_fav_artists_transform.to_csv('fuente/transformacion/albums_fav_artists.csv', sep='|', index=False)

# %%
df_albums_fav_artists_transform.to_excel('fuente/transformacion/albums_fav_artists.xlsx', index=False)

# %%
df_top_tracks_fav_artists_transform.to_csv('fuente/transformacion/top_tracks_fav_artists.csv', sep='|', index=False)

# %%
df_top_tracks_fav_artists_transform.to_excel('fuente/transformacion/top_tracks_fav_artists.xlsx', index=False)

# %%
df_user_top_artists_transform.to_csv('fuente/transformacion/user_top_artists.csv', sep='|', index=False)

# %%
df_user_top_artists_transform.to_excel('fuente/transformacion/user_top_artists.xlsx', index=False)

# %%
df_top_albums_fav_artists_transform.to_csv('fuente/transformacion/top_albums_fav_artists.csv', sep='|', index=False)

# %%
df_top_albums_fav_artists_transform.to_excel('fuente/transformacion/top_albums_fav_artists.xlsx', index=False)
